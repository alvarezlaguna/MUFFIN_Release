# %% [markdown]
# # Multi-fluid modeling of a sheath in an isothermal weakly-ionized collisionless plasma

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
if (code_show){
$('div.input').hide();
} else {
$('div.input').show();
}
code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="This documment is written in a Jupyter notebook and the code used to produce these analyses has been hidden for ease of reading.  
To make the code visible click here"></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
# if (code_show){
# $('div.input').hide();
# } else {
# $('div.input').show();
# }
# code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="This documment is written in a Jupyter notebook and the code used to produce these analyses has been hidden for ease of reading.
# To make the code visible click here"></form>

# %% [markdown]
# We present the solutions of a weakly-ionized collisionless plasma between two floating plates. The set of equations that are solved are as follow
#
# $$\partial_t n_e + \partial_x \left( n_e u_e \right) = n_e \text{Da} $$
# $$\partial_t n_i + \partial_x \left( n_i u_i \right) = n_e \text{Da} $$
# $$\partial_t \left(n_eu_e\right) + \partial_x \left( n_e (u_e^2 + \epsilon^{-1})\right) = \frac{n_e}{\epsilon}\partial_x\phi - \nu_e n_e u_e $$
# $$\partial_t \left(n_iu_i\right) + \partial_x \left( n_i (u_i^2 + \kappa)\right) = -n_i\partial_x\phi - \nu_i n_i u_i $$
# $$\lambda^2\partial^2_{xx}\phi = n_e - n_i $$

# %% [markdown]
# The numerical scheme features:
#
#  - TVD second order reconstruction
#  - ospre limiter
#  - Forward Euler (1st order for a steady solution)
#  - Roe scheme
#  - Thomas algorithm

# %% [markdown]
# The simulation allows for choosing for the following degrees of freedom
#
#  - $\epsilon$
#  - $\kappa$
#  - $\nu_e$
#  - $\nu_i$
#  - $\lambda_D/L$

# %% [markdown]
# The ionization is not a proper degree of freedom as it is an eigenvalue of the system to find a steady solution. We compute the ionization as a function of the ion wall flux every time step, as follows
#
# $$\text{Da} = \frac{2\left|\Gamma_{i_w}\right|}{<n_e>L}$$
#
# where the average density is computed as $$<n_e>L = \int_0^L n_e dx$$

# %% [markdown]
# ## Case Study 1

# %% [markdown]
# We study the following conditions:
#
# $$\epsilon^{-1} = 73451.7$$
# $$T_i/T_e = 0.025$$
# $$\nu_e = 56.7$$
# $$\nu_i = 0$$
# $$L/\lambda_D = 50$$
#
# - Limiter: osper
# - Reconstruction : Second order
# - Results directory: Results_Isothermal_2ndOrderNominal
#
# See next cell for input parameters

# %%
nbCells = 500
InitialField = [0 for i in range(4*nbCells)]
# Set Density of Electrons
for iCell in range(nbCells):
       InitialField[0*nbCells + iCell] = 1.
# Set Momentum of Electrons
for iCell in range(nbCells):
       InitialField[1*nbCells + iCell] = 0.
# Set Density of Ions
for iCell in range(nbCells):
       InitialField[2*nbCells + iCell] = 1.
# Set Momentum of Ions
for iCell in range(nbCells):
       InitialField[3*nbCells + iCell] = 0.

# Set Mesh
mesh = [0 for i in range(nbCells)]
for iCell in range(nbCells):
       length   = 50.
       delta_X = length/nbCells
       mesh[iCell] = delta_X/2. + iCell*delta_X
        
# Set Phi Initial
PhiInitial = [0 for i in range(nbCells)]

options = {
        'nbEqs':4,
        'nbFluids':2,
        'nbCells':nbCells,
        'geometry':"1D",
        'mesh':mesh,
        'stopCondition':{'type':"nbSteps",'value':9e6},
        #'stopCondition':{'type':"Residual",'value':-12},
        'Inlet':{'type':"TwoFluidIsothermalSheath",},
        'Outlet':{'type':"TwoFluidIsothermalSheath",},
        'PhysicalModel':{
                'type':"MultiFluidIsothermal1D",
                'soundSpeed': [np.sqrt(73451.7), np.sqrt(0.025)],
                },
        'SourceTerm':{
                'type':"TwoFluidIsothermal1D",
                'massRatio':73451.7,
                'DebyeLength':1.,
                'ionizConst':1.,
                'epsIoniz':8.72,
                'CollIons':0.,
                'CollElectrons':100./1.76187519204,
                'PhiIn':0.,
                'PhiOut':0.,
                'PhiInitial':PhiInitial,
                },
        'CFL':0.1,
        'saveRate':10000,
        'resultDir':"./Results_Isothermal_2ndOrder",
        'limiter':"ospre",
        'reconstruction':"TVD2ndOrder1D",#"TVD2ndOrder1D",1stOrder"
        'fluxScheme':"RoeMultiFluidIsothermal1D",#"LaxFriedrich",
        'initialField':InitialField,
}

# %% [markdown]
# Press Shift+enter to read results

# %%
import sys  
import os
import numpy as np
# IMPORT PATH TO PYTHONTOOLS MODULE
sys.path.append('../PythonTools') 

import plotResults
import tkinter as tk
from tkinter import filedialog

# %gui tk

root = tk.Tk()
root.withdraw()

currentPath = os.getcwd()
filename = filedialog.askopenfilename(parent=root, initialdir=currentPath)
root.destroy()
print('Reading %s' % filename)

results = []
with open(filename, 'r') as data:
    j = 0                   # counter of the lines of the file
    for line in data:
        p = line.split()
        results.append(np.array(p))

# Transpose and change data type
results = np.array(results)
resultsTP = np.transpose(results)

resultsTP   = resultsTP.astype(np.float)        

plotData = plotResults.Data(resultsTP)
# Initializing without the results to choose it directly by hand
#plotData2 = plotResults.Data()

print("NbEqs = ", plotData.nbEqs)
print("NbCells = ",plotData.nbCells)

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
n_e = plotData.resultsArray[1]
n_i = plotData.resultsArray[3]

ax.plot(x, n_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, n_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$n$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Density', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(n_e)
ymax = max(n_e)
ax.set_ylim([0,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
nU_e = plotData.resultsArray[2]
nU_i = plotData.resultsArray[4]

ax.plot(x, nU_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, nU_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$nu$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Flux', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(nU_e)
ymax = max(nU_e)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
U_e = nU_e[:]/n_e[:]
U_i = nU_i[:]/n_i[:]

ax.plot(x, U_i, color=(255/255,97/255,3/255), linewidth=2, markersize=3, label ='Ions')
ax.plot(x, U_e, linestyle='--', color='k', linewidth=2, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$u$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Velocity', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(U_i)
ymax = max(U_i)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
phi = plotData.resultsArray[5]

MASSRATIO = 73451.7;
phi_W    = np.log((MASSRATIO/(2*np.pi))**(1/2))*np.ones(x.size);
phi_P    = (phi_W + 0.5)*np.ones(x.size);

ax.plot(x, phi_W, color=(0, 0.4, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi_P, color=(0, 0.6, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi, color=(61/255,89/255,171/255), linewidth=1.8, markersize=3, label ='Potential')

ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$\phi$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
#plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Potential', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

plt.text(0.9*max(x),1.04*max(phi_W),r'$\phi_W$',fontsize=13,color=(0, 0.4, 0), weight = 'bold')
plt.text(0.9*max(x),1.04*max(phi_P),r'$\phi_p$',fontsize=13,color=(0, 0.6, 0), weight = 'bold')

ymin = min(phi)
ymax = max(phi)
ax.set_ylim([ymin,1.2*ymax])
ax.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-7f284d59d611> in <module>()
#       4
#       5 x   = plotData.resultsArray[0]
# ----> 6 phi = plotData.resultsArray[5]
#       7
#       8 MASSRATIO = 73451.7;
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %% [markdown]
# ## Case 2: Hot ions

# %% [markdown]
# We study the following conditions:
#
# $$\epsilon^{-1} = 73451.7$$
# $$T_i/T_e = 1$$
# $$\nu_e = 56.7$$
# $$\nu_i = 0$$
# $$L/\lambda_D = 50$$
#
# - Limiter: osper
# - Reconstruction : Second order
# - Results directory: Results_Isothermal_2ndOrder_HotIons
#
# See next cell for input parameters

# %%
nbCells = 500
InitialField = [0 for i in range(4*nbCells)]
# Set Density of Electrons
for iCell in range(nbCells):
       InitialField[0*nbCells + iCell] = 1.
# Set Momentum of Electrons
for iCell in range(nbCells):
       InitialField[1*nbCells + iCell] = 0.
# Set Density of Ions
for iCell in range(nbCells):
       InitialField[2*nbCells + iCell] = 1.
# Set Momentum of Ions
for iCell in range(nbCells):
       InitialField[3*nbCells + iCell] = 0.

# Set Mesh
mesh = [0 for i in range(nbCells)]
for iCell in range(nbCells):
       length   = 50.
       delta_X = length/nbCells
       mesh[iCell] = delta_X/2. + iCell*delta_X
        
# Set Phi Initial
PhiInitial = [0 for i in range(nbCells)]

options = {
        'nbEqs':4,
        'nbFluids':2,
        'nbCells':nbCells,
        'geometry':"1D",
        'mesh':mesh,
        'stopCondition':{'type':"nbSteps",'value':9e6},
        #'stopCondition':{'type':"Residual",'value':-12},
        'Inlet':{'type':"TwoFluidIsothermalSheath",},
        'Outlet':{'type':"TwoFluidIsothermalSheath",},
        'PhysicalModel':{
                'type':"MultiFluidIsothermal1D",
                'soundSpeed': [np.sqrt(73451.7), 1.],
                },
        'SourceTerm':{
                'type':"TwoFluidIsothermal1D",
                'massRatio':73451.7,
                'DebyeLength':1.,
                'ionizConst':1.,
                'epsIoniz':8.72,
                'CollIons':0.,
                'CollElectrons':100./1.76187519204,
                'PhiIn':0.,
                'PhiOut':0.,
                'PhiInitial':PhiInitial,
                },
        'CFL':0.1,
        'saveRate':10000,
        'resultDir':"./Results_Isothermal_2ndOrder",
        'limiter':"ospre",
        'reconstruction':"TVD2ndOrder1D",#"TVD2ndOrder1D",1stOrder"
        'fluxScheme':"RoeMultiFluidIsothermal1D",#"LaxFriedrich",
        'initialField':InitialField,
}

# %%
import sys  
import os
import numpy as np
# IMPORT PATH TO PYTHONTOOLS MODULE
sys.path.append('./PythonTools') 

import plotResults
import tkinter as tk
from tkinter import filedialog

# %gui tk

root = tk.Tk()
root.withdraw()

currentPath = os.getcwd()
filename = filedialog.askopenfilename(parent=root, initialdir=currentPath)
root.destroy()
print('Reading %s' % filename)

results = []
with open(filename, 'r') as data:
    j = 0                   # counter of the lines of the file
    for line in data:
        p = line.split()
        results.append(np.array(p))

# Transpose and change data type
results = np.array(results)
resultsTP = np.transpose(results)

resultsTP   = resultsTP.astype(np.float)        

plotData = plotResults.Data(resultsTP)
# Initializing without the results to choose it directly by hand
#plotData2 = plotResults.Data()

print("NbEqs = ", plotData.nbEqs)
print("NbCells = ",plotData.nbCells)
# Out:
# Reading /Users/alaguna/Documents/16_PostDoc/16_C++Code/1_ProceduralCode/EulerIsothermalProcedural/EulerIsothermalProcedural/Results_Isothermal_2ndOrder_HotIons/file_iter_9000000.txt
# NbEqs =  5
# NbCells =  500

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
n_e = plotData.resultsArray[1]
n_i = plotData.resultsArray[3]

ax.plot(x, n_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, n_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$n$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Density', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(n_e)
ymax = max(n_e)
ax.set_ylim([0,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
nU_e = plotData.resultsArray[2]
nU_i = plotData.resultsArray[4]

ax.plot(x, nU_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, nU_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$nu$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Flux', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(nU_e)
ymax = max(nU_e)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
U_e = nU_e[:]/n_e[:]
U_i = nU_i[:]/n_i[:]

ax.plot(x, U_i, color=(255/255,97/255,3/255), linewidth=2, markersize=3, label ='Ions')
ax.plot(x, U_e, linestyle='--', color='k', linewidth=2, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$u$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Velocity', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(U_i)
ymax = max(U_i)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
phi = plotData.resultsArray[5]

MASSRATIO = 73451.7;
phi_W    = np.log((MASSRATIO/(2*np.pi))**(1/2))*np.ones(x.size);
phi_P    = (phi_W + 0.5)*np.ones(x.size);

ax.plot(x, phi_W, color=(0, 0.4, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi_P, color=(0, 0.6, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi, color=(61/255,89/255,171/255), linewidth=1.8, markersize=3, label ='Potential')

ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$\phi$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
#plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Potential', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

plt.text(0.9*max(x),1.04*max(phi_W),r'$\phi_W$',fontsize=13,color=(0, 0.4, 0), weight = 'bold')
plt.text(0.9*max(x),1.04*max(phi_P),r'$\phi_p$',fontsize=13,color=(0, 0.6, 0), weight = 'bold')

ymin = min(phi)
ymax = max(phi)
ax.set_ylim([ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %% [markdown]
# ## Case 3: Colder ions

# %% [markdown]
# We study the following conditions:
#
# $$\epsilon^{-1} = 73451.7$$
# $$T_i/T_e = 0.0025$$
# $$\nu_e = 56.7$$
# $$\nu_i = 0$$
# $$L/\lambda_D = 50$$
#
# - Limiter: osper
# - Reconstruction : Second order
# - Results directory: Results_Isothermal_2ndOrder_kappa_0_0025
#
# See next cell for input parameters

# %%
nbCells = 500
InitialField = [0 for i in range(4*nbCells)]
# Set Density of Electrons
for iCell in range(nbCells):
       InitialField[0*nbCells + iCell] = 1.
# Set Momentum of Electrons
for iCell in range(nbCells):
       InitialField[1*nbCells + iCell] = 0.
# Set Density of Ions
for iCell in range(nbCells):
       InitialField[2*nbCells + iCell] = 1.
# Set Momentum of Ions
for iCell in range(nbCells):
       InitialField[3*nbCells + iCell] = 0.

# Set Mesh
mesh = [0 for i in range(nbCells)]
for iCell in range(nbCells):
       length   = 50.
       delta_X = length/nbCells
       mesh[iCell] = delta_X/2. + iCell*delta_X

options = {
        'nbEqs':4,
        'nbFluids':2,
        'nbCells':nbCells,
        'geometry':"1D",
        'mesh':mesh,
        'stopCondition':{'type':"nbSteps",'value':9e6},
        #'stopCondition':{'type':"Residual",'value':-12},
        'Inlet':{'type':"TwoFluidIsothermalSheath",},
        'Outlet':{'type':"TwoFluidIsothermalSheath",},
        'PhysicalModel':{
                'type':"MultiFluidIsothermal1D",
                'soundSpeed': [np.sqrt(73451.7), np.sqrt(0.0025)],
                },
        'SourceTerm':{
                'type':"TwoFluidIsothermal1D",
                'massRatio':73451.7,
                'DebyeLength':1.,
                'ionizConst':1.,
                'epsIoniz':8.72,
                'CollIons':0.,
                'CollElectrons':100./1.76187519204,
                'PhiIn':0.,
                'PhiOut':0.,
                },
        'CFL':0.1,
        'saveRate':10000,
        'resultDir':"./Results_Isothermal_2ndOrder",
        'limiter':"ospre",
        'reconstruction':"TVD2ndOrder1D",#"TVD2ndOrder1D",1stOrder"
        'fluxScheme':"RoeMultiFluidIsothermal1D",#"LaxFriedrich",
        'initialField':InitialField,
}

# %%
import sys  
import os
import numpy as np
# IMPORT PATH TO PYTHONTOOLS MODULE
sys.path.append('./PythonTools') 

import plotResults
import tkinter as tk
from tkinter import filedialog

# %gui tk

root = tk.Tk()
root.withdraw()

currentPath = os.getcwd()
filename = filedialog.askopenfilename(parent=root, initialdir=currentPath)
root.destroy()
print('Reading %s' % filename)

results = []
with open(filename, 'r') as data:
    j = 0                   # counter of the lines of the file
    for line in data:
        p = line.split()
        results.append(np.array(p))

# Transpose and change data type
results = np.array(results)
resultsTP = np.transpose(results)

resultsTP   = resultsTP.astype(np.float)        

plotData = plotResults.Data(resultsTP)
# Initializing without the results to choose it directly by hand
#plotData2 = plotResults.Data()

print("NbEqs = ", plotData.nbEqs)
print("NbCells = ",plotData.nbCells)
# Out:
# Reading /Users/alaguna/Documents/16_PostDoc/16_C++Code/1_ProceduralCode/EulerIsothermalProcedural/EulerIsothermalProcedural/Results_Isothermal_2ndOrder_kappa_0_0025/file_iter_9000000.txt
# NbEqs =  5
# NbCells =  500

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
n_e = plotData.resultsArray[1]
n_i = plotData.resultsArray[3]

ax.plot(x, n_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, n_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$n$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Density', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(n_e)
ymax = max(n_e)
ax.set_ylim([0,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
nU_e = plotData.resultsArray[2]
nU_i = plotData.resultsArray[4]

ax.plot(x, nU_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, nU_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$nu$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Flux', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(nU_e)
ymax = max(nU_e)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
U_e = nU_e[:]/n_e[:]
U_i = nU_i[:]/n_i[:]

ax.plot(x, U_i, color=(255/255,97/255,3/255), linewidth=2, markersize=3, label ='Ions')
ax.plot(x, U_e, linestyle='--', color='k', linewidth=2, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$u$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Velocity', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(U_i)
ymax = max(U_i)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
phi = plotData.resultsArray[5]

MASSRATIO = 73451.7;
phi_W    = np.log((MASSRATIO/(2*np.pi))**(1/2))*np.ones(x.size);
phi_P    = (phi_W + 0.5)*np.ones(x.size);

ax.plot(x, phi_W, color=(0, 0.4, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi_P, color=(0, 0.6, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi, color=(61/255,89/255,171/255), linewidth=1.8, markersize=3, label ='Potential')

ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$\phi$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
#plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Potential', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

plt.text(0.9*max(x),1.04*max(phi_W),r'$\phi_W$',fontsize=13,color=(0, 0.4, 0), weight = 'bold')
plt.text(0.9*max(x),1.04*max(phi_P),r'$\phi_p$',fontsize=13,color=(0, 0.6, 0), weight = 'bold')

ymin = min(phi)
ymax = max(phi)
ax.set_ylim([ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %% [markdown]
# ## Case 4: Larger Domain

# %% [markdown]
# We study the following conditions:
#
# $$\epsilon^{-1} = 73451.7$$
# $$T_i/T_e = 0.0025$$
# $$\nu_e = 56.7$$
# $$\nu_i = 0$$
# $$L/\lambda_D = 100$$
#
# - Limiter: osper
# - Reconstruction : Second order
# - Results directory: Results_Isothermal_2ndOrder_BigDomain_restart
#
# See next cell for input parameters

# %%
nbCells = 500
InitialField = [0 for i in range(4*nbCells)]
# Set Density of Electrons
for iCell in range(nbCells):
       InitialField[0*nbCells + iCell] = 1.
# Set Momentum of Electrons
for iCell in range(nbCells):
       InitialField[1*nbCells + iCell] = 0.
# Set Density of Ions
for iCell in range(nbCells):
       InitialField[2*nbCells + iCell] = 1.
# Set Momentum of Ions
for iCell in range(nbCells):
       InitialField[3*nbCells + iCell] = 0.

# Set Mesh
mesh = [0 for i in range(nbCells)]
for iCell in range(nbCells):
       length   = 50.
       delta_X = length/nbCells
       mesh[iCell] = delta_X/2. + iCell*delta_X

options = {
        'nbEqs':4,
        'nbFluids':2,
        'nbCells':nbCells,
        'geometry':"1D",
        'mesh':mesh,
        'stopCondition':{'type':"nbSteps",'value':9e6},
        #'stopCondition':{'type':"Residual",'value':-12},
        'Inlet':{'type':"TwoFluidIsothermalSheath",},
        'Outlet':{'type':"TwoFluidIsothermalSheath",},
        'PhysicalModel':{
                'type':"MultiFluidIsothermal1D",
                'soundSpeed': [np.sqrt(73451.7), np.sqrt(0.0025)],
                },
        'SourceTerm':{
                'type':"TwoFluidIsothermal1D",
                'massRatio':73451.7,
                'DebyeLength':1.,
                'ionizConst':1.,
                'epsIoniz':8.72,
                'CollIons':0.,
                'CollElectrons':100./1.76187519204,
                'PhiIn':0.,
                'PhiOut':0.,
                },
        'CFL':0.1,
        'saveRate':10000,
        'resultDir':"./Results_Isothermal_2ndOrder",
        'limiter':"ospre",
        'reconstruction':"TVD2ndOrder1D",#"TVD2ndOrder1D",1stOrder"
        'fluxScheme':"RoeMultiFluidIsothermal1D",#"LaxFriedrich",
        'initialField':InitialField,
}

# %%
import sys  
import os
import numpy as np
# IMPORT PATH TO PYTHONTOOLS MODULE
sys.path.append('./PythonTools') 

import plotResults
import tkinter as tk
from tkinter import filedialog

# %gui tk

root = tk.Tk()
root.withdraw()

currentPath = os.getcwd()
filename = filedialog.askopenfilename(parent=root, initialdir=currentPath)
root.destroy()
print('Reading %s' % filename)

results = []
with open(filename, 'r') as data:
    j = 0                   # counter of the lines of the file
    for line in data:
        p = line.split()
        results.append(np.array(p))

# Transpose and change data type
results = np.array(results)
resultsTP = np.transpose(results)

resultsTP   = resultsTP.astype(np.float)        

plotData = plotResults.Data(resultsTP)
# Initializing without the results to choose it directly by hand
#plotData2 = plotResults.Data()

print("NbEqs = ", plotData.nbEqs)
print("NbCells = ",plotData.nbCells)
# Out:
# Reading /Users/alaguna/Documents/16_PostDoc/16_C++Code/1_ProceduralCode/EulerIsothermalProcedural/EulerIsothermalProcedural/Results_Isothermal_2ndOrder_BigDomain_restart/file_iter_9000000.txt
# NbEqs =  5
# NbCells =  1000

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
n_e = plotData.resultsArray[1]
n_i = plotData.resultsArray[3]

ax.plot(x, n_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, n_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$n$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Density', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(n_e)
ymax = max(n_e)
ax.set_ylim([0,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
nU_e = plotData.resultsArray[2]
nU_i = plotData.resultsArray[4]

ax.plot(x, nU_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, nU_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$nu$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Flux', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(nU_e)
ymax = max(nU_e)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
U_e = nU_e[:]/n_e[:]
U_i = nU_i[:]/n_i[:]

ax.plot(x, U_i, color=(255/255,97/255,3/255), linewidth=2, markersize=3, label ='Ions')
ax.plot(x, U_e, linestyle='--', color='k', linewidth=2, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$u$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Velocity', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(U_i)
ymax = max(U_i)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
phi = plotData.resultsArray[5]

MASSRATIO = 73451.7;
phi_W    = np.log((MASSRATIO/(2*np.pi))**(1/2))*np.ones(x.size);
phi_P    = (phi_W + 0.5)*np.ones(x.size);

ax.plot(x, phi_W, color=(0, 0.4, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi_P, color=(0, 0.6, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi, color=(61/255,89/255,171/255), linewidth=1.8, markersize=3, label ='Potential')

ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$\phi$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
#plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Potential', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

plt.text(0.9*max(x),1.04*max(phi_W),r'$\phi_W$',fontsize=13,color=(0, 0.4, 0), weight = 'bold')
plt.text(0.9*max(x),1.04*max(phi_P),r'$\phi_p$',fontsize=13,color=(0, 0.6, 0), weight = 'bold')

ymin = min(phi)
ymax = max(phi)
ax.set_ylim([ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %% [markdown]
# ## Case 5: Collisional Case

# %% [markdown]
# We study the following conditions:
#
# $$\epsilon^{-1} = 73451.7$$
# $$T_i/T_e = 0.0025$$
# $$\nu_e = 56.7$$
# $$\nu_i = 10$$
# $$L/\lambda_D = 50$$
#
# - Limiter: osper
# - Reconstruction : Second order
# - Results directory: Results_Isothermal_2ndOrder_Collisions
#
# See next cell for input parameters

# %%
nbCells = 500
InitialField = [0 for i in range(4*nbCells)]
# Set Density of Electrons
for iCell in range(nbCells):
       InitialField[0*nbCells + iCell] = 1.
# Set Momentum of Electrons
for iCell in range(nbCells):
       InitialField[1*nbCells + iCell] = 0.
# Set Density of Ions
for iCell in range(nbCells):
       InitialField[2*nbCells + iCell] = 1.
# Set Momentum of Ions
for iCell in range(nbCells):
       InitialField[3*nbCells + iCell] = 0.

# Set Mesh
mesh = [0 for i in range(nbCells)]
for iCell in range(nbCells):
       length   = 50.
       delta_X = length/nbCells
       mesh[iCell] = delta_X/2. + iCell*delta_X

options = {
        'nbEqs':4,
        'nbFluids':2,
        'nbCells':nbCells,
        'geometry':"1D",
        'mesh':mesh,
        'stopCondition':{'type':"nbSteps",'value':9e6},
        #'stopCondition':{'type':"Residual",'value':-12},
        'Inlet':{'type':"TwoFluidIsothermalSheath",},
        'Outlet':{'type':"TwoFluidIsothermalSheath",},
        'PhysicalModel':{
                'type':"MultiFluidIsothermal1D",
                'soundSpeed': [np.sqrt(73451.7), np.sqrt(0.0025)],
                },
        'SourceTerm':{
                'type':"TwoFluidIsothermal1D",
                'massRatio':73451.7,
                'DebyeLength':1.,
                'ionizConst':1.,
                'epsIoniz':8.72,
                'CollIons':0.,
                'CollElectrons':100./1.76187519204,
                'PhiIn':0.,
                'PhiOut':0.,
                },
        'CFL':0.1,
        'saveRate':10000,
        'resultDir':"./Results_Isothermal_2ndOrder",
        'limiter':"ospre",
        'reconstruction':"TVD2ndOrder1D",#"TVD2ndOrder1D",1stOrder"
        'fluxScheme':"RoeMultiFluidIsothermal1D",#"LaxFriedrich",
        'initialField':InitialField,
}

# %%
import sys  
import os
import numpy as np
# IMPORT PATH TO PYTHONTOOLS MODULE
sys.path.append('./PythonTools') 

import plotResults
import tkinter as tk
from tkinter import filedialog

# %gui tk

root = tk.Tk()
root.withdraw()

currentPath = os.getcwd()
filename = filedialog.askopenfilename(parent=root, initialdir=currentPath)
root.destroy()
print('Reading %s' % filename)

results = []
with open(filename, 'r') as data:
    j = 0                   # counter of the lines of the file
    for line in data:
        p = line.split()
        results.append(np.array(p))

# Transpose and change data type
results = np.array(results)
resultsTP = np.transpose(results)

resultsTP   = resultsTP.astype(np.float)        

plotData = plotResults.Data(resultsTP)
# Initializing without the results to choose it directly by hand
#plotData2 = plotResults.Data()

print("NbEqs = ", plotData.nbEqs)
print("NbCells = ",plotData.nbCells)
# Out:
# Reading /Users/alaguna/Documents/16_PostDoc/16_C++Code/1_ProceduralCode/EulerIsothermalProcedural/EulerIsothermalProcedural/Results_Isothermal_2ndOrder_Collisions_restart/file_iter_9000000.txt
# NbEqs =  5
# NbCells =  500

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
n_e = plotData.resultsArray[1]
n_i = plotData.resultsArray[3]

ax.plot(x, n_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, n_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$n$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Density', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(n_e)
ymax = max(n_e)
ax.set_ylim([0,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
nU_e = plotData.resultsArray[2]
nU_i = plotData.resultsArray[4]

ax.plot(x, nU_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, nU_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$nu$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Flux', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(nU_e)
ymax = max(nU_e)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
U_e = nU_e[:]/n_e[:]
U_i = nU_i[:]/n_i[:]

ax.plot(x, U_i, color=(255/255,97/255,3/255), linewidth=2, markersize=3, label ='Ions')
ax.plot(x, U_e, linestyle='--', color='k', linewidth=2, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$u$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Velocity', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(U_i)
ymax = max(U_i)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
phi = plotData.resultsArray[5]

MASSRATIO = 73451.7;
phi_W    = np.log((MASSRATIO/(2*np.pi))**(1/2))*np.ones(x.size);
phi_P    = (phi_W + 0.5)*np.ones(x.size);

ax.plot(x, phi_W, color=(0, 0.4, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi_P, color=(0, 0.6, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi, color=(61/255,89/255,171/255), linewidth=1.8, markersize=3, label ='Potential')

ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$\phi$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
#plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Potential', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

plt.text(0.9*max(x),1.04*max(phi_W),r'$\phi_W$',fontsize=13,color=(0, 0.4, 0), weight = 'bold')
plt.text(0.9*max(x),1.04*max(phi_P),r'$\phi_p$',fontsize=13,color=(0, 0.6, 0), weight = 'bold')

ymin = min(phi)
ymax = max(phi)
ax.set_ylim([ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %% [markdown]
# ## Case 6: Nominal case in third order

# %% [markdown]
# We study the following conditions:
#
# $$\epsilon^{-1} = 73451.7$$
# $$T_i/T_e = 0.0025$$
# $$\nu_e = 56.7$$
# $$\nu_i = 10$$
# $$L/\lambda_D = 50$$
#
# - Limiter: thirdOrder
# - Reconstruction : third order
# - Results directory: Results_Isothermal_3rdOrder_TVDRK3
#
# See next cell for input parameters

# %%
nbCells = 500
InitialField = [0 for i in range(4*nbCells)]
# Set Density of Electrons
for iCell in range(nbCells):
       InitialField[0*nbCells + iCell] = 1.
# Set Momentum of Electrons
for iCell in range(nbCells):
       InitialField[1*nbCells + iCell] = 0.
# Set Density of Ions
for iCell in range(nbCells):
       InitialField[2*nbCells + iCell] = 1.
# Set Momentum of Ions
for iCell in range(nbCells):
       InitialField[3*nbCells + iCell] = 0.

# Set Mesh
mesh = [0 for i in range(nbCells)]
for iCell in range(nbCells):
       length   = 50.
       delta_X = length/nbCells
       mesh[iCell] = delta_X/2. + iCell*delta_X

options = {
        'nbEqs':4,
        'nbFluids':2,
        'nbCells':nbCells,
        'geometry':"1D",
        'mesh':mesh,
        'stopCondition':{'type':"nbSteps",'value':9e6},
        #'stopCondition':{'type':"Residual",'value':-12},
        'Inlet':{'type':"TwoFluidIsothermalSheath",},
        'Outlet':{'type':"TwoFluidIsothermalSheath",},
        'PhysicalModel':{
                'type':"MultiFluidIsothermal1D",
                'soundSpeed': [np.sqrt(73451.7), np.sqrt(0.0025)],
                },
        'SourceTerm':{
                'type':"TwoFluidIsothermal1D",
                'massRatio':73451.7,
                'DebyeLength':1.,
                'ionizConst':1.,
                'epsIoniz':8.72,
                'CollIons':0.,
                'CollElectrons':100./1.76187519204,
                'PhiIn':0.,
                'PhiOut':0.,
                },
        'CFL':0.1,
        'saveRate':10000,
        'resultDir':"./Results_Isothermal_2ndOrder",
        'limiter':"ospre",
        'reconstruction':"TVD2ndOrder1D",#"TVD2ndOrder1D",1stOrder"
        'fluxScheme':"RoeMultiFluidIsothermal1D",#"LaxFriedrich",
        'initialField':InitialField,
}

# %%
import sys  
import os
import numpy as np
# IMPORT PATH TO PYTHONTOOLS MODULE
sys.path.append('./PythonTools') 

import plotResults
import tkinter as tk
from tkinter import filedialog

# %gui tk

root = tk.Tk()
root.withdraw()

currentPath = os.getcwd()
filename = filedialog.askopenfilename(parent=root, initialdir=currentPath)
root.destroy()
print('Reading %s' % filename)

results = []
with open(filename, 'r') as data:
    j = 0                   # counter of the lines of the file
    for line in data:
        p = line.split()
        results.append(np.array(p))

# Transpose and change data type
results = np.array(results)
resultsTP = np.transpose(results)

resultsTP   = resultsTP.astype(np.float)        

plotData = plotResults.Data(resultsTP)
# Initializing without the results to choose it directly by hand
#plotData2 = plotResults.Data()

print("NbEqs = ", plotData.nbEqs)
print("NbCells = ",plotData.nbCells)
# Out:
# Reading /Users/alaguna/Documents/16_PostDoc/16_C++Code/1_ProceduralCode/EulerIsothermalProcedural/EulerIsothermalProcedural/Results_Isothermal_2ndOrder_TVDRK3/file_iter_4100000.txt
# NbEqs =  5
# NbCells =  500

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
n_e = plotData.resultsArray[1]
n_i = plotData.resultsArray[3]

ax.plot(x, n_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, n_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$n$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Density', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(n_e)
ymax = max(n_e)
ax.set_ylim([0,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
nU_e = plotData.resultsArray[2]
nU_i = plotData.resultsArray[4]

ax.plot(x, nU_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, nU_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$nu$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Flux', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(nU_e)
ymax = max(nU_e)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
U_e = nU_e[:]/n_e[:]
U_i = nU_i[:]/n_i[:]

ax.plot(x, U_i, color=(255/255,97/255,3/255), linewidth=2, markersize=3, label ='Ions')
ax.plot(x, U_e, linestyle='--', color='k', linewidth=2, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$u$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Velocity', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(U_i)
ymax = max(U_i)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
phi = plotData.resultsArray[5]

MASSRATIO = 73451.7;
phi_W    = np.log((MASSRATIO/(2*np.pi))**(1/2))*np.ones(x.size);
phi_P    = (phi_W + 0.5)*np.ones(x.size);

ax.plot(x, phi_W, color=(0, 0.4, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi_P, color=(0, 0.6, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi, color=(61/255,89/255,171/255), linewidth=1.8, markersize=3, label ='Potential')

ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$\phi$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
#plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Potential', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

plt.text(0.9*max(x),1.04*max(phi_W),r'$\phi_W$',fontsize=13,color=(0, 0.4, 0), weight = 'bold')
plt.text(0.9*max(x),1.04*max(phi_P),r'$\phi_p$',fontsize=13,color=(0, 0.6, 0), weight = 'bold')

ymin = min(phi)
ymax = max(phi)
ax.set_ylim([ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %% [markdown]
# ## Case 7: Nominal case in third order without electron collisions and Hagelaar boundary

# %% [markdown]
# We study the following conditions:
#
# $$\epsilon^{-1} = 73451.7$$
# $$T_i/T_e = 0.0025$$
# $$\nu_e = 0$$
# $$\nu_i = 0$$
# $$L/\lambda_D = 50$$
#
# - Limiter: osper
# - Reconstruction : Second order
# - Results directory: Results_Isothermal_2ndOrder_Collisions
#
# See next cell for input parameters

# %%
nbCells = 500
InitialField = [0 for i in range(4*nbCells)]
# Set Density of Electrons
for iCell in range(nbCells):
       InitialField[0*nbCells + iCell] = 1.
# Set Momentum of Electrons
for iCell in range(nbCells):
       InitialField[1*nbCells + iCell] = 0.
# Set Density of Ions
for iCell in range(nbCells):
       InitialField[2*nbCells + iCell] = 1.
# Set Momentum of Ions
for iCell in range(nbCells):
       InitialField[3*nbCells + iCell] = 0.

# Set Mesh
mesh = [0 for i in range(nbCells)]
for iCell in range(nbCells):
       length   = 50.
       delta_X = length/nbCells
       mesh[iCell] = delta_X/2. + iCell*delta_X

options = {
        'nbEqs':4,
        'nbFluids':2,
        'nbCells':nbCells,
        'geometry':"1D",
        'mesh':mesh,
        'stopCondition':{'type':"nbSteps",'value':9e6},
        #'stopCondition':{'type':"Residual",'value':-12},
        'Inlet':{'type':"TwoFluidIsothermalSheath",},
        'Outlet':{'type':"TwoFluidIsothermalSheath",},
        'PhysicalModel':{
                'type':"MultiFluidIsothermal1D",
                'soundSpeed': [np.sqrt(73451.7), np.sqrt(0.0025)],
                },
        'SourceTerm':{
                'type':"TwoFluidIsothermal1D",
                'massRatio':73451.7,
                'DebyeLength':1.,
                'ionizConst':1.,
                'epsIoniz':8.72,
                'CollIons':0.,
                'CollElectrons':100./1.76187519204,
                'PhiIn':0.,
                'PhiOut':0.,
                },
        'CFL':0.1,
        'saveRate':10000,
        'resultDir':"./Results_Isothermal_2ndOrder",
        'limiter':"ospre",
        'reconstruction':"TVD2ndOrder1D",#"TVD2ndOrder1D",1stOrder"
        'fluxScheme':"RoeMultiFluidIsothermal1D",#"LaxFriedrich",
        'initialField':InitialField,
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35cbf2313cb6> in <module>()
#      33         'PhysicalModel':{
#      34                 'type':"MultiFluidIsothermal1D",
# ---> 35                 'soundSpeed': [np.sqrt(73451.7), np.sqrt(0.0025)],
#      36                 },
#      37         'SourceTerm':{
#
# NameError: name 'np' is not defined

# %%
import sys  
import os
import numpy as np

# IMPORT PATH TO PYTHONTOOLS MODULE
sys.path.append('./PythonTools') 

import plotResults

import tkinter as tk
from tkinter import filedialog

# %gui tk

root = tk.Tk()
root.withdraw()

currentPath = os.getcwd()
filename = filedialog.askopenfilename(parent=root, initialdir=currentPath)
root.destroy()
print('Reading %s' % filename)

results = []
with open(filename, 'r') as data:
    j = 0                   # counter of the lines of the file
    for line in data:
        p = line.split()
        results.append(np.array(p))

# Transpose and change data type
results = np.array(results)
resultsTP = np.transpose(results)

resultsTP   = resultsTP.astype(np.float)        

plotData = plotResults.Data(resultsTP)
# Initializing without the results to choose it directly by hand
#plotData2 = plotResults.Data()

print("NbEqs = ", plotData.nbEqs)
print("NbCells = ",plotData.nbCells)
# Out:
# Reading /Users/alaguna/Documents/16_PostDoc/16_C++Code/1_ProceduralCode/EulerIsothermalProcedural/EulerIsothermalProcedural/Results_Isothermal_3rdOrder_TVDRK3_FluxElec_NoColls/file_iter_1300000.txt
# NbEqs =  5
# NbCells =  500

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
n_e = plotData.resultsArray[1]
n_i = plotData.resultsArray[3]

ax.plot(x, n_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, n_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$n$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Density', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(n_e)
ymax = max(n_e)
ax.set_ylim([0,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
nU_e = plotData.resultsArray[2]
nU_i = plotData.resultsArray[4]

ax.plot(x, nU_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, nU_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$nu$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Flux', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(nU_e)
ymax = max(nU_e)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
U_e = nU_e[:]/n_e[:]
U_i = nU_i[:]/n_i[:]

ax.plot(x, U_i, color=(255/255,97/255,3/255), linewidth=2, markersize=3, label ='Ions')
ax.plot(x, U_e, linestyle='--', color='k', linewidth=2, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$u$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Velocity', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(U_i)
ymax = max(U_i)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
phi = plotData.resultsArray[5]

MASSRATIO = 73451.7;
phi_W    = np.log((MASSRATIO/(2*np.pi))**(1/2))*np.ones(x.size);
phi_P    = (phi_W + 0.5)*np.ones(x.size);

ax.plot(x, phi_W, color=(0, 0.4, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi_P, color=(0, 0.6, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi, color=(61/255,89/255,171/255), linewidth=1.8, markersize=3, label ='Potential')

ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$\phi$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
#plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Potential', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

plt.text(0.9*max(x),1.04*max(phi_W),r'$\phi_W$',fontsize=13,color=(0, 0.4, 0), weight = 'bold')
plt.text(0.9*max(x),1.04*max(phi_P),r'$\phi_p$',fontsize=13,color=(0, 0.6, 0), weight = 'bold')

ymin = min(phi)
ymax = max(phi)
ax.set_ylim([ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %% [markdown]
# ## Case 8: Nominal case in third order without electron collisions and Hagelaar boundary larger domain

# %% [markdown]
# We study the following conditions:
#
# $$\epsilon^{-1} = 73451.7$$
# $$T_i/T_e = 0.0025$$
# $$\nu_e = 0$$
# $$\nu_i = 0$$
# $$L/\lambda_D = 100$$
#
# - Limiter: osper
# - Reconstruction : Second order
# - Results directory: Results_Isothermal_2ndOrder_Collisions
#
# See next cell for input parameters

# %%
nbCells = 500
InitialField = [0 for i in range(4*nbCells)]
# Set Density of Electrons
for iCell in range(nbCells):
       InitialField[0*nbCells + iCell] = 1.
# Set Momentum of Electrons
for iCell in range(nbCells):
       InitialField[1*nbCells + iCell] = 0.
# Set Density of Ions
for iCell in range(nbCells):
       InitialField[2*nbCells + iCell] = 1.
# Set Momentum of Ions
for iCell in range(nbCells):
       InitialField[3*nbCells + iCell] = 0.

# Set Mesh
mesh = [0 for i in range(nbCells)]
for iCell in range(nbCells):
       length   = 50.
       delta_X = length/nbCells
       mesh[iCell] = delta_X/2. + iCell*delta_X

options = {
        'nbEqs':4,
        'nbFluids':2,
        'nbCells':nbCells,
        'geometry':"1D",
        'mesh':mesh,
        'stopCondition':{'type':"nbSteps",'value':9e6},
        #'stopCondition':{'type':"Residual",'value':-12},
        'Inlet':{'type':"TwoFluidIsothermalSheath",},
        'Outlet':{'type':"TwoFluidIsothermalSheath",},
        'PhysicalModel':{
                'type':"MultiFluidIsothermal1D",
                'soundSpeed': [np.sqrt(73451.7), np.sqrt(0.0025)],
                },
        'SourceTerm':{
                'type':"TwoFluidIsothermal1D",
                'massRatio':73451.7,
                'DebyeLength':1.,
                'ionizConst':1.,
                'epsIoniz':8.72,
                'CollIons':0.,
                'CollElectrons':100./1.76187519204,
                'PhiIn':0.,
                'PhiOut':0.,
                },
        'CFL':0.1,
        'saveRate':10000,
        'resultDir':"./Results_Isothermal_2ndOrder",
        'limiter':"ospre",
        'reconstruction':"TVD2ndOrder1D",#"TVD2ndOrder1D",1stOrder"
        'fluxScheme':"RoeMultiFluidIsothermal1D",#"LaxFriedrich",
        'initialField':InitialField,
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35cbf2313cb6> in <module>()
#      33         'PhysicalModel':{
#      34                 'type':"MultiFluidIsothermal1D",
# ---> 35                 'soundSpeed': [np.sqrt(73451.7), np.sqrt(0.0025)],
#      36                 },
#      37         'SourceTerm':{
#
# NameError: name 'np' is not defined

# %%
import sys  
import os
import numpy as np

# IMPORT PATH TO PYTHONTOOLS MODULE
sys.path.append('./PythonTools') 

import plotResults

import tkinter as tk
from tkinter import filedialog

# %gui tk

root = tk.Tk()
root.withdraw()

currentPath = os.getcwd()
filename = filedialog.askopenfilename(parent=root, initialdir=currentPath)
root.destroy()
print('Reading %s' % filename)

results = []
with open(filename, 'r') as data:
    j = 0                   # counter of the lines of the file
    for line in data:
        p = line.split()
        results.append(np.array(p))

# Transpose and change data type
results = np.array(results)
resultsTP = np.transpose(results)

resultsTP   = resultsTP.astype(np.float)        

plotData = plotResults.Data(resultsTP)
# Initializing without the results to choose it directly by hand
#plotData2 = plotResults.Data()

print("NbEqs = ", plotData.nbEqs)
print("NbCells = ",plotData.nbCells)
# Out:
# Reading /Users/alaguna/Documents/16_PostDoc/16_C++Code/1_ProceduralCode/EulerIsothermalProcedural/EulerIsothermalProcedural/Results_Isothermal_3rdOrder_TVDRK3_FluxElec_NoColls_LargeDomain/file_iter_2780000.txt
# NbEqs =  5
# NbCells =  1000

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
n_e = plotData.resultsArray[1]
n_i = plotData.resultsArray[3]

ax.plot(x, n_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, n_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$n$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Density', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(n_e)
ymax = max(n_e)
ax.set_ylim([0,1.2*ymax])
ax.grid(True)
plt.show()

# %%
print("n_i average = ", np.average(n_i))
print("n_e average = ", np.average(n_e))
# Out:
# n_i average =  1.000000046
# n_e average =  0.97327806452

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
nU_e = plotData.resultsArray[2]
nU_i = plotData.resultsArray[4]

ax.plot(x, nU_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, nU_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$nu$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Flux', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(nU_e)
ymax = max(nU_e)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
U_e = nU_e[:]/n_e[:]
U_i = nU_i[:]/n_i[:]

ax.plot(x, U_i, color=(255/255,97/255,3/255), linewidth=2, markersize=3, label ='Ions')
ax.plot(x, U_e, linestyle='--', color='k', linewidth=2, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$u$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Velocity', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(U_i)
ymax = max(U_i)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
phi = plotData.resultsArray[5]

MASSRATIO = 73451.7;
phi_W    = np.log((MASSRATIO/(2*np.pi))**(1/2))*np.ones(x.size);
phi_P    = (phi_W + 0.5)*np.ones(x.size);

ax.plot(x, phi_W, color=(0, 0.4, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi_P, color=(0, 0.6, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi, color=(61/255,89/255,171/255), linewidth=1.8, markersize=3, label ='Potential')

ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$\phi$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
#plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Potential', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

plt.text(0.9*max(x),1.04*max(phi_W),r'$\phi_W$',fontsize=13,color=(0, 0.4, 0), weight = 'bold')
plt.text(0.9*max(x),1.04*max(phi_P),r'$\phi_p$',fontsize=13,color=(0, 0.6, 0), weight = 'bold')

ymin = min(phi)
ymax = max(phi)
ax.set_ylim([ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %% [markdown]
# ## Case 9: Nominal case in third order without electron collisions and Hagelaar boundary larger domain, 1000 Debye lengths

# %% [markdown]
# We study the following conditions:
#
# $$\epsilon^{-1} = 73451.7$$
# $$T_i/T_e = 0.0025$$
# $$\nu_e = 0$$
# $$\nu_i = 0$$
# $$L/\lambda_D = 1000$$
#
# - Limiter: osper
# - Reconstruction : Third order
# - Results directory: Results_Isothermal_2ndOrder_Collisions
#
# See next cell for input parameters

# %%
nbCells = 500
InitialField = [0 for i in range(4*nbCells)]
# Set Density of Electrons
for iCell in range(nbCells):
       InitialField[0*nbCells + iCell] = 1.
# Set Momentum of Electrons
for iCell in range(nbCells):
       InitialField[1*nbCells + iCell] = 0.
# Set Density of Ions
for iCell in range(nbCells):
       InitialField[2*nbCells + iCell] = 1.
# Set Momentum of Ions
for iCell in range(nbCells):
       InitialField[3*nbCells + iCell] = 0.

# Set Mesh
mesh = [0 for i in range(nbCells)]
for iCell in range(nbCells):
       length   = 50.
       delta_X = length/nbCells
       mesh[iCell] = delta_X/2. + iCell*delta_X

options = {
        'nbEqs':4,
        'nbFluids':2,
        'nbCells':nbCells,
        'geometry':"1D",
        'mesh':mesh,
        'stopCondition':{'type':"nbSteps",'value':9e6},
        #'stopCondition':{'type':"Residual",'value':-12},
        'Inlet':{'type':"TwoFluidIsothermalSheath",},
        'Outlet':{'type':"TwoFluidIsothermalSheath",},
        'PhysicalModel':{
                'type':"MultiFluidIsothermal1D",
                'soundSpeed': [np.sqrt(73451.7), np.sqrt(0.0025)],
                },
        'SourceTerm':{
                'type':"TwoFluidIsothermal1D",
                'massRatio':73451.7,
                'DebyeLength':1.,
                'ionizConst':1.,
                'epsIoniz':8.72,
                'CollIons':0.,
                'CollElectrons':100./1.76187519204,
                'PhiIn':0.,
                'PhiOut':0.,
                },
        'CFL':0.1,
        'saveRate':10000,
        'resultDir':"./Results_Isothermal_2ndOrder",
        'limiter':"ospre",
        'reconstruction':"TVD2ndOrder1D",#"TVD2ndOrder1D",1stOrder"
        'fluxScheme':"RoeMultiFluidIsothermal1D",#"LaxFriedrich",
        'initialField':InitialField,
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35cbf2313cb6> in <module>()
#      33         'PhysicalModel':{
#      34                 'type':"MultiFluidIsothermal1D",
# ---> 35                 'soundSpeed': [np.sqrt(73451.7), np.sqrt(0.0025)],
#      36                 },
#      37         'SourceTerm':{
#
# NameError: name 'np' is not defined

# %%
import sys  
import os
import numpy as np

# IMPORT PATH TO PYTHONTOOLS MODULE
sys.path.append('./PythonTools') 

import plotResults

import tkinter as tk
from tkinter import filedialog

# %gui tk

root = tk.Tk()
root.withdraw()

currentPath = os.getcwd()
filename = filedialog.askopenfilename(parent=root, initialdir=currentPath)
root.destroy()
print('Reading %s' % filename)

results = []
with open(filename, 'r') as data:
    j = 0                   # counter of the lines of the file
    for line in data:
        p = line.split()
        results.append(np.array(p))

# Transpose and change data type
results = np.array(results)
resultsTP = np.transpose(results)

resultsTP   = resultsTP.astype(np.float)        

plotData = plotResults.Data(resultsTP)
# Initializing without the results to choose it directly by hand
#plotData2 = plotResults.Data()

print("NbEqs = ", plotData.nbEqs)
print("NbCells = ",plotData.nbCells)
# Out:
# Reading /Users/alaguna/Documents/16_PostDoc/16_C++Code/1_ProceduralCode/EulerIsothermalProcedural/EulerIsothermalProcedural/Results_Isothermal_3rdOrder_TVDRK3_FluxElec_NoColls_LargeDomain_1000_restart/file_iter_3200000.txt
# NbEqs =  5
# NbCells =  10000

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
n_e = plotData.resultsArray[1]
n_i = plotData.resultsArray[3]

ax.plot(x, n_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, n_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$n$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Density', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(n_e)
ymax = max(n_e)
ax.set_ylim([0,1.2*ymax])
ax.grid(True)
plt.show()

# %%
print("n_i average = ", np.average(n_i))
print("n_e average = ", np.average(n_e))
# Out:
# n_i average =  0.9999999308
# n_e average =  0.997602856548

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
nU_e = plotData.resultsArray[2]
nU_i = plotData.resultsArray[4]

ax.plot(x, nU_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, nU_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$nu$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Flux', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(nU_e)
ymax = max(nU_e)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
U_e = nU_e[:]/n_e[:]
U_i = nU_i[:]/n_i[:]

ax.plot(x, U_i, color=(255/255,97/255,3/255), linewidth=2, markersize=3, label ='Ions')
ax.plot(x, U_e, linestyle='--', color='k', linewidth=2, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$u$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Velocity', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(U_i)
ymax = max(U_i)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
phi = plotData.resultsArray[5]

MASSRATIO = 73451.7;
phi_W    = np.log((MASSRATIO/(2*np.pi))**(1/2))*np.ones(x.size);
phi_P    = (phi_W + 0.5)*np.ones(x.size);

ax.plot(x, phi_W, color=(0, 0.4, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi_P, color=(0, 0.6, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi, color=(61/255,89/255,171/255), linewidth=1.8, markersize=3, label ='Potential')

ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$\phi$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
#plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Potential', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

plt.text(0.9*max(x),1.04*max(phi_W),r'$\phi_W$',fontsize=13,color=(0, 0.4, 0), weight = 'bold')
plt.text(0.9*max(x),1.04*max(phi_P),r'$\phi_p$',fontsize=13,color=(0, 0.6, 0), weight = 'bold')

ymin = min(phi)
ymax = max(phi)
ax.set_ylim([ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import sys  
import os
import numpy as np

# IMPORT PATH TO PYTHONTOOLS MODULE
sys.path.append('./PythonTools') 

import plotResults

import tkinter as tk
from tkinter import filedialog

# %gui tk

root = tk.Tk()
root.withdraw()

currentPath = os.getcwd()
filename = filedialog.askopenfilename(parent=root, initialdir=currentPath)
root.destroy()
print('Reading %s' % filename)

results = []
with open(filename, 'r') as data:
    j = 0                   # counter of the lines of the file
    for line in data:
        p = line.split()
        results.append(np.array(p))

# Transpose and change data type
results = np.array(results)
resultsTP = np.transpose(results)

resultsTP   = resultsTP.astype(np.float)        

plotData = plotResults.Data(resultsTP)
# Initializing without the results to choose it directly by hand
#plotData2 = plotResults.Data()

print("NbEqs = ", plotData.nbEqs)
print("NbCells = ",plotData.nbCells)
# Out:
# Reading /Users/alaguna/Documents/16_PostDoc/16_C++Code/1_ProceduralCode/EulerIsothermalProcedural/EulerIsothermalProcedural/1_RESULTS_GEC/Results_Isothermal_3Order_TVDRK3_100Debye_1000_CFL_0_9/file_iter_2567000_time_562.9317.txt
# NbEqs =  5
# NbCells =  1000

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
n_e = plotData.resultsArray[1]
n_i = plotData.resultsArray[3]

ax.plot(x, n_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, n_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$n$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Density', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(n_e)
ymax = max(n_e)
ax.set_ylim([0,1.2*ymax])
ax.grid(True)
plt.show()

# %%
print("n_i average = ", np.average(n_i))
print("n_e average = ", np.average(n_e))
# Out:
# n_i average =  0.999999984
# n_e average =  0.97327797252

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
nU_e = plotData.resultsArray[2]
nU_i = plotData.resultsArray[4]

ax.plot(x, nU_i, color=(255/255,97/255,3/255), linewidth=1.8, markersize=3, label ='Ions')
ax.plot(x, nU_e, linestyle='--', color='k', linewidth=1.8, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$nu$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Flux', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(nU_e)
ymax = max(nU_e)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt         ## plots

plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
U_e = nU_e[:]/n_e[:]
U_i = nU_i[:]/n_i[:]

ax.plot(x, U_i, color=(255/255,97/255,3/255), linewidth=2, markersize=3, label ='Ions')
ax.plot(x, U_e, linestyle='--', color='k', linewidth=2, markersize=3, label ='Electrons')
ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$u$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Velocity', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

ymin = min(U_i)
ymax = max(U_i)
ax.set_ylim([1.2*ymin,1.2*ymax])
ax.grid(True)
plt.show()

# %%
plt.rcParams["font.family"] = 'Times New Roman'

f, ax = plt.subplots(1)

x   = plotData.resultsArray[0]
phi = plotData.resultsArray[5]

MASSRATIO = 73451.7;
phi_W    = np.log((MASSRATIO/(2*np.pi))**(1/2))*np.ones(x.size);
phi_P    = (phi_W + 0.5)*np.ones(x.size);

ax.plot(x, phi_W, color=(0, 0.4, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi_P, color=(0, 0.6, 0), linewidth=1.8, markersize=3)
ax.plot(x, phi, color=(61/255,89/255,171/255), linewidth=1.8, markersize=3, label ='Potential')

ax.set_xlabel(r'$x/\lambda$', fontsize=18, weight = 'bold')
ax.set_ylabel(r'$\phi$', fontsize=18)
ax.xaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
ax.yaxis.set_tick_params(which='both', size=5, width=1.5, labelsize=13)
#plt.legend(loc = 'lower center', fontsize = 12)

f.suptitle('Potential', fontname = 'Times New Roman',fontsize=16, weight = 'bold')

plt.text(0.9*max(x),1.04*max(phi_W),r'$\phi_W$',fontsize=13,color=(0, 0.4, 0), weight = 'bold')
plt.text(0.9*max(x),1.04*max(phi_P),r'$\phi_p$',fontsize=13,color=(0, 0.6, 0), weight = 'bold')

ymin = min(phi)
ymax = max(phi)
ax.set_ylim([ymin,1.2*ymax])
ax.grid(True)
plt.show()
