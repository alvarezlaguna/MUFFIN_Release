# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Curve-fits-for-the-collisional-rates-in-Argon" data-toc-modified-id="Curve-fits-for-the-collisional-rates-in-Argon-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Curve fits for the collisional rates in Argon</a></span><ul class="toc-item"><li><span><a href="#Electron-collisions" data-toc-modified-id="Electron-collisions-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Electron collisions</a></span></li></ul></li><li><span><a href="#Ar-+-e$^--\rightarrow$-Ar$^*$-+-e$^-$" data-toc-modified-id="Ar-+-e$^--\rightarrow$-Ar$^*$-+-e$^-$-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Ar + e$^- \rightarrow$ Ar$^*$ + e$^-$</a></span><ul class="toc-item"><li><span><a href="#Sum-of-excitation" data-toc-modified-id="Sum-of-excitation-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Sum of excitation</a></span></li><li><span><a href="#Sum-of-de-excitation" data-toc-modified-id="Sum-of-de-excitation-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Sum of de-excitation</a></span></li></ul></li><li><span><a href="#Ar$^*$-+-e$^--\rightarrow$-Ar$^{**}$-+-e$^-$" data-toc-modified-id="Ar$^*$-+-e$^--\rightarrow$-Ar$^{**}$-+-e$^-$-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Ar$^*$ + e$^- \rightarrow$ Ar$^{**}$ + e$^-$</a></span><ul class="toc-item"><li><span><a href="#4s-$\rightarrow$-4p" data-toc-modified-id="4s-$\rightarrow$-4p-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>4s $\rightarrow$ 4p</a></span><ul class="toc-item"><li><span><a href="#Sum-of-excitation-from-4s" data-toc-modified-id="Sum-of-excitation-from-4s-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Sum of excitation from 4s</a></span></li></ul></li><li><span><a href="#4s-$\rightarrow$-5s-and-3d" data-toc-modified-id="4s-$\rightarrow$-5s-and-3d-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>4s $\rightarrow$ 5s and 3d</a></span><ul class="toc-item"><li><span><a href="#Sum-of-excitation-from-4s-to-5s-and-3d" data-toc-modified-id="Sum-of-excitation-from-4s-to-5s-and-3d-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Sum of excitation from 4s to 5s and 3d</a></span></li></ul></li><li><span><a href="#Total-stepwise-excitation" data-toc-modified-id="Total-stepwise-excitation-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Total stepwise excitation</a></span></li></ul></li><li><span><a href="#Make-LPPiC-file" data-toc-modified-id="Make-LPPiC-file-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Make LPPiC file</a></span></li><li><span><a href="#Plot-the-average-rate-integrated-over-a-Maxwellian" data-toc-modified-id="Plot-the-average-rate-integrated-over-a-Maxwellian-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Plot the average rate integrated over a Maxwellian</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Plot-the-$\Omega^{(1,1)}$" data-toc-modified-id="Plot-the-$\Omega^{(1,1)}$-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Plot the $\Omega^{(1,1)}$</a></span></li><li><span><a href="#Plot-the-fit-of-the-rates" data-toc-modified-id="Plot-the-fit-of-the-rates-5.0.2"><span class="toc-item-num">5.0.2&nbsp;&nbsp;</span>Plot the fit of the rates</a></span></li></ul></li><li><span><a href="#Ion-collisions" data-toc-modified-id="Ion-collisions-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Ion collisions</a></span><ul class="toc-item"><li><span><a href="#Plot-the-momentum-transfer-cross-sections" data-toc-modified-id="Plot-the-momentum-transfer-cross-sections-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Plot the momentum transfer cross-sections</a></span></li><li><span><a href="#Plot-the-rate-integrated-over-a-Maxwellian" data-toc-modified-id="Plot-the-rate-integrated-over-a-Maxwellian-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Plot the rate integrated over a Maxwellian</a></span></li><li><span><a href="#Plot-the-fit-of-the-rates" data-toc-modified-id="Plot-the-fit-of-the-rates-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Plot the fit of the rates</a></span></li></ul></li></ul></li><li><span><a href="#Reference-values" data-toc-modified-id="Reference-values-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Reference values</a></span></li></ul></div>

# %% [markdown]
# # Curve fits for the collisional rates in Argon

# %%
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
plt.style.use('classic')
plt.rcParams["font.family"] = 'Times New Roman'
plt.rcParams["font.weight"] = 'normal'
plt.rcParams['figure.facecolor'] = 'white'

import numpy as np

import scipy.constants as phy_const
from scipy import integrate
from scipy import interpolate

from scipy.optimize import curve_fit 
import sys
np.set_printoptions(threshold=np.inf)

plt.rcParams["font.family"]   = 'Times New Roman'
plt.rcParams["font.size"] = 15
plt.rcParams["lines.linewidth"] = 2

# %% [markdown]
# We read the collisions used by the PIC simulation. We define the momentum transfer cross-section, as follows
#
# $$ \sigma_m = 2\pi \int^\pi_0  (1 - cos \theta) I(v, \theta) \sin \theta d \theta, $$
#
# where
#
# $$ I(v, \theta) = \frac{b}{\sin \theta} \left| \frac{db}{d \theta} \right|. $$
#
# Here, $I(v, \theta)$ is the differential cross-section, b is the impact paramiter, and $\theta$ is the scattering angle

# %% [markdown]
# We define a class that compute the methods for the cross-section

# %%
import sys  
import os
import numpy as np

# IMPORT PATH TO PYTHONTOOLS MODULE"
sys.path.append('../src/CollisionalData')

import CrossSection as CS

from datetime import date
today = date.today()

# mm/dd/y
day = today.strftime("%m/%d/%y")

# %% [markdown]
# ## Electron collisions

# %%
# Define the cross-section
sigma_en_el    = CS.CrossSection("Ar-e (Elastic)")

# Ground to 4s
sigma_en_exc_4s_32_2 = CS.CrossSection("Ar-e (4s[3/2]2)", potential = 11.549)
sigma_en_exc_4s_32_1 = CS.CrossSection("Ar-e (4s[3/2]1)", potential = 11.624)
sigma_en_exc_4s_12_0 = CS.CrossSection("Ar-e (4s'[1/2]0)", potential = 11.723)
sigma_en_exc_4s_12_1 = CS.CrossSection("Ar-e (4s'[1/2]1)", potential = 11.828)

sigma_en_exc_4s_32_2.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_11_549.txt")
sigma_en_exc_4s_32_1.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_11_624.txt")
sigma_en_exc_4s_12_0.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_11_723.txt")
sigma_en_exc_4s_12_1.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_11_828.txt")


sigma_Gr_4s = [sigma_en_exc_4s_32_2, sigma_en_exc_4s_32_1, sigma_en_exc_4s_12_0, sigma_en_exc_4s_12_1]

# Ground to 4s with Cascade
sigma_en_exc_4s_32_2_casc = CS.CrossSection("Ar-e casc. (4s[3/2]2)", potential = 11.549 )
sigma_en_exc_4s_32_1_casc = CS.CrossSection("Ar-e casc. (4s[3/2]1)", potential = 11.624 )
sigma_en_exc_4s_12_0_casc = CS.CrossSection("Ar-e casc. (4s'[1/2]0)", potential = 11.723)
sigma_en_exc_4s_12_1_casc = CS.CrossSection("Ar-e casc. (4s'[1/2]1)", potential = 11.828)

sigma_en_exc_4s_32_2_casc.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATIONCASCADE_11_549.txt", units='a2')
sigma_en_exc_4s_32_1_casc.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATIONCASCADE_11_624.txt", units='a2')
sigma_en_exc_4s_12_0_casc.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATIONCASCADE_11_723.txt", units='a2')
sigma_en_exc_4s_12_1_casc.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATIONCASCADE_11_828.txt", units='a2')


sigma_Gr_4s_casc = [sigma_en_exc_4s_32_2_casc, sigma_en_exc_4s_32_1_casc, sigma_en_exc_4s_12_0_casc, sigma_en_exc_4s_12_1_casc]


# Ground to 4s to 4p

sigma_en_exc_4s2_1  = CS.CrossSection("Ar-e (4s'[1/2]1->4p[1/2]1)", potential = 1.246)
sigma_en_exc_4s2_2  = CS.CrossSection("Ar-e (4s'[1/2]1->4p[5/2]3)", potential = 1.376)
sigma_en_exc_4s2_3  = CS.CrossSection("Ar-e (4s'[1/2]1->4p[5/2]2)", potential = 1.399)
sigma_en_exc_4s2_4  = CS.CrossSection("Ar-e (4s'[1/2]1->4p[3/2]1)", potential = 1.448)
sigma_en_exc_4s2_5  = CS.CrossSection("Ar-e (4s'[1/2]1->4p[3/2]2)", potential = 1.471)
sigma_en_exc_4s2_6  = CS.CrossSection("Ar-e (4s'[1/2]1->4p[1/2]0)", potential = 1.568)
sigma_en_exc_4s2_7  = CS.CrossSection("Ar-e (4s'[1/2]1->4p'[3/2]1)", potential = 1.569)
sigma_en_exc_4s2_8  = CS.CrossSection("Ar-e (4s'[1/2]1->4p'[3/2]2)", potential = 1.590)
sigma_en_exc_4s2_9  = CS.CrossSection("Ar-e (4s'[1/2]1->4p'[1/2]1)", potential = 1.614)
sigma_en_exc_4s2_10 = CS.CrossSection("Ar-e (4s'[1/2]1->4p'[1/2]0)", potential = 1.766)

sigma_en_exc_4s2_1.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s2_1_246.txt")
sigma_en_exc_4s2_2.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s2_1_376.txt")
sigma_en_exc_4s2_3.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s2_1_399.txt")
sigma_en_exc_4s2_4.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s2_1_448.txt")
sigma_en_exc_4s2_5.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s2_1_471.txt")
sigma_en_exc_4s2_6.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s2_1_568.txt")
sigma_en_exc_4s2_7.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s2_1_569.txt")
sigma_en_exc_4s2_8.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s2_1_590.txt")
sigma_en_exc_4s2_9.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s2_1_614.txt")
sigma_en_exc_4s2_10.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s2_1_766.txt")

sigma_4s2_4p = [sigma_en_exc_4s2_1, sigma_en_exc_4s2_2,sigma_en_exc_4s2_3,sigma_en_exc_4s2_4,sigma_en_exc_4s2_5, sigma_en_exc_4s2_6, sigma_en_exc_4s2_7, sigma_en_exc_4s2_8, sigma_en_exc_4s2_9, sigma_en_exc_4s2_10]


sigma_en_exc_4s3_1  = CS.CrossSection("Ar-e (4s'[1/2]0->4p[1/2]1)", potential = 1.351)
sigma_en_exc_4s3_2  = CS.CrossSection("Ar-e (4s'[1/2]0->4p[5/2]3)", potential = 1.481)
sigma_en_exc_4s3_3  = CS.CrossSection("Ar-e (4s'[1/2]0->4p[5/2]2)", potential = 1.504)
sigma_en_exc_4s3_4  = CS.CrossSection("Ar-e (4s'[1/2]0->4p[3/2]1)", potential = 1.553)
sigma_en_exc_4s3_5  = CS.CrossSection("Ar-e (4s'[1/2]0->4p[3/2]2)", potential = 1.576)
sigma_en_exc_4s3_6  = CS.CrossSection("Ar-e (4s'[1/2]0->4p[1/2]0)", potential = 1.673)
sigma_en_exc_4s3_7  = CS.CrossSection("Ar-e (4s'[1/2]0->4p'[3/2]1)", potential = 1.674)
sigma_en_exc_4s3_8  = CS.CrossSection("Ar-e (4s'[1/2]0->4p'[3/2]2)", potential = 1.695)
sigma_en_exc_4s3_9  = CS.CrossSection("Ar-e (4s'[1/2]0->4p'[1/2]1)", potential = 1.719)
sigma_en_exc_4s3_10 = CS.CrossSection("Ar-e (4s'[1/2]0->4p'[1/2]0)", potential = 1.871)

sigma_en_exc_4s3_1.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s3_1_351.txt")
sigma_en_exc_4s3_2.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s3_1_481.txt")
sigma_en_exc_4s3_3.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s3_1_504.txt")
sigma_en_exc_4s3_4.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s3_1_553.txt")
sigma_en_exc_4s3_5.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s3_1_576.txt")
sigma_en_exc_4s3_6.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s3_1_673.txt")
sigma_en_exc_4s3_7.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s3_1_674.txt")
sigma_en_exc_4s3_8.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s3_1_695.txt")
sigma_en_exc_4s3_9.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s3_1_719.txt")
sigma_en_exc_4s3_10.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s3_1_871.txt")

sigma_4s3_4p = [sigma_en_exc_4s3_1, sigma_en_exc_4s3_2,sigma_en_exc_4s3_3,sigma_en_exc_4s3_4,sigma_en_exc_4s3_5, sigma_en_exc_4s3_6, sigma_en_exc_4s3_7, sigma_en_exc_4s3_8, sigma_en_exc_4s3_9, sigma_en_exc_4s3_10]


sigma_en_exc_4s4_1  = CS.CrossSection("Ar-e (4s[3/2]1->4p[1/2]1)", potential = 1.45)
sigma_en_exc_4s4_2  = CS.CrossSection("Ar-e (4s[3/2]1->4p[5/2]3)", potential = 1.58)
sigma_en_exc_4s4_3  = CS.CrossSection("Ar-e (4s[3/2]1->4p[5/2]2)", potential = 1.603)
sigma_en_exc_4s4_4  = CS.CrossSection("Ar-e (4s[3/2]1->4p[3/2]1)", potential = 1.652)
sigma_en_exc_4s4_5  = CS.CrossSection("Ar-e (4s[3/2]1->4p[3/2]2)", potential = 1.675)
sigma_en_exc_4s4_6  = CS.CrossSection("Ar-e (4s[3/2]1->4p[1/2]0)", potential = 1.772)
sigma_en_exc_4s4_7  = CS.CrossSection("Ar-e (4s[3/2]1->4p'[3/2]1)", potential = 1.773)
sigma_en_exc_4s4_8  = CS.CrossSection("Ar-e (4s[3/2]1->4p'[3/2]2)", potential = 1.794)
sigma_en_exc_4s4_9  = CS.CrossSection("Ar-e (4s[3/2]1->4p'[1/2]1)", potential = 1.818)
sigma_en_exc_4s4_10 = CS.CrossSection("Ar-e (4s[3/2]1->4p'[1/2]0)", potential = 1.970)

sigma_en_exc_4s4_1.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s4_1_450.txt")
sigma_en_exc_4s4_2.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s4_1_580.txt")
sigma_en_exc_4s4_3.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s4_1_603.txt")
sigma_en_exc_4s4_4.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s4_1_652.txt")
sigma_en_exc_4s4_5.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s4_1_675.txt")
sigma_en_exc_4s4_6.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s4_1_772.txt")
sigma_en_exc_4s4_7.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s4_1_773.txt")
sigma_en_exc_4s4_8.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s4_1_794.txt")
sigma_en_exc_4s4_9.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s4_1_818.txt")
sigma_en_exc_4s4_10.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s4_1_970.txt")

sigma_4s4_4p = [sigma_en_exc_4s4_1, sigma_en_exc_4s4_2,sigma_en_exc_4s4_3,sigma_en_exc_4s4_4,
                sigma_en_exc_4s4_5, sigma_en_exc_4s4_6, sigma_en_exc_4s4_7, sigma_en_exc_4s4_8, sigma_en_exc_4s4_9, sigma_en_exc_4s4_10]


sigma_en_exc_4s5_1  = CS.CrossSection("Ar-e (4s[3/2]2->4p[1/2]1)", potential = 1.525)
sigma_en_exc_4s5_2  = CS.CrossSection("Ar-e (4s[3/2]2->4p[5/2]3)", potential = 1.655)
sigma_en_exc_4s5_3  = CS.CrossSection("Ar-e (4s[3/2]2->4p[5/2]2)", potential = 1.678)
sigma_en_exc_4s5_4  = CS.CrossSection("Ar-e (4s[3/2]2->4p[3/2]1)", potential = 1.727)
sigma_en_exc_4s5_5  = CS.CrossSection("Ar-e (4s[3/2]2->4p[3/2]2)", potential = 1.750)
sigma_en_exc_4s5_6  = CS.CrossSection("Ar-e (4s[3/2]2->4p[1/2]0)", potential = 1.847)
sigma_en_exc_4s5_7  = CS.CrossSection("Ar-e (4s[3/2]2->4p'[3/2]1)", potential = 1.848)
sigma_en_exc_4s5_8  = CS.CrossSection("Ar-e (4s[3/2]2->4p'[3/2]2)", potential = 1.869)
sigma_en_exc_4s5_9  = CS.CrossSection("Ar-e (4s[3/2]2->4p'[1/2]1)", potential = 1.893)
sigma_en_exc_4s5_10 = CS.CrossSection("Ar-e (4s[3/2]2->4p'[1/2]0)", potential = 2.045)

sigma_en_exc_4s5_1.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s5_1_525.txt")
sigma_en_exc_4s5_2.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s5_1_655.txt")
sigma_en_exc_4s5_3.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s5_1_678.txt")
sigma_en_exc_4s5_4.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s5_1_727.txt")
sigma_en_exc_4s5_5.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s5_1_750.txt")
sigma_en_exc_4s5_6.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s5_1_847.txt")
sigma_en_exc_4s5_7.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s5_1_848.txt")
sigma_en_exc_4s5_8.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s5_1_869.txt")
sigma_en_exc_4s5_9.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s5_1_893.txt")
sigma_en_exc_4s5_10.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_4s5_2_045.txt")

sigma_4s5_4p = [sigma_en_exc_4s5_1, sigma_en_exc_4s5_2, sigma_en_exc_4s5_3, sigma_en_exc_4s5_4,
                sigma_en_exc_4s5_5, sigma_en_exc_4s5_6, sigma_en_exc_4s5_7, sigma_en_exc_4s5_8, sigma_en_exc_4s5_9, sigma_en_exc_4s5_10]


# 4s to 4p with cascade
sigma_exc_4s_4p_sum_casc = CS.CrossSection("Ar(4s)-e (4p) casc", potential = 1.45, category='EXCITATION',
                                      param='E = %.2f'%(1.45),
                                      species = ['e', 'Ar_4s'], process='E + Ar_4s -> Ar_*(13.00 eV) + E, Excitation',
                                      updated=day)

sigma_exc_4s_4p_sum_casc.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATIONCASCADE_4s4p.txt", units='a2')


# Ground to 4s to 5s 3d

sigma_en_exc_4s2_11  = CS.CrossSection("Ar-e (4s'[1/2]1->3d[1/2]0)", potential = 2.241)
sigma_en_exc_4s2_12  = CS.CrossSection("Ar-e (4s'[1/2]1->3d[1/2]1)", potential = 2.253)
sigma_en_exc_4s2_13  = CS.CrossSection("Ar-e (4s'[1/2]1->3d[3/2]2)", potential = 2.272)
sigma_en_exc_4s2_14  = CS.CrossSection("Ar-e (4s'[1/2]1->3d[7/2]4)", potential = 2.321)
sigma_en_exc_4s2_15  = CS.CrossSection("Ar-e (4s'[1/2]1->5s[3/2]2)", potential = 2.336)
sigma_en_exc_4s2_16  = CS.CrossSection("Ar-e (4s'[1/2]1->3d[7/2]3)", potential = 2.337)
sigma_en_exc_4s2_17  = CS.CrossSection("Ar-e (4s'[1/2]1->5s[3/2]1)", potential = 2.351)
sigma_en_exc_4s2_18  = CS.CrossSection("Ar-e (4s'[1/2]1->3d[5/2]2)", potential = 2.373)
sigma_en_exc_4s2_19  = CS.CrossSection("Ar-e (4s'[1/2]1->3d[5/2]3)", potential = 2.384)
sigma_en_exc_4s2_20 = CS.CrossSection("Ar-e (4s'[1/2]1->3d[3/2]1)", potential = 2.399)
sigma_en_exc_4s2_21 = CS.CrossSection("Ar-e (4s'[1/2]1->5s'[1/2]0)", potential = 2.484)
sigma_en_exc_4s2_22 = CS.CrossSection("Ar-e (4s'[1/2]1->5s'[1/2]1)", potential = 2.502)
sigma_en_exc_4s2_23 = CS.CrossSection("Ar-e (4s'[1/2]1->3d'[5/2]2)", potential = 2.509)
sigma_en_exc_4s2_24 = CS.CrossSection("Ar-e (4s'[1/2]1->3d'[3/2]2)", potential = 2.515)
sigma_en_exc_4s2_25 = CS.CrossSection("Ar-e (4s'[1/2]1->3d'[5/2]3)", potential = 2.52)
sigma_en_exc_4s2_26 = CS.CrossSection("Ar-e (4s'[1/2]1->3d'[3/2]1)", potential = 2.548)


sigma_en_exc_4s2_11.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_241.txt")
sigma_en_exc_4s2_12.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_253.txt")
sigma_en_exc_4s2_13.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_272.txt")
sigma_en_exc_4s2_14.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_321.txt")
sigma_en_exc_4s2_15.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_336.txt")
sigma_en_exc_4s2_16.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_337.txt")
sigma_en_exc_4s2_17.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_351.txt")
sigma_en_exc_4s2_18.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_373.txt")
sigma_en_exc_4s2_19.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_384.txt")
sigma_en_exc_4s2_20.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_399.txt")
sigma_en_exc_4s2_21.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_484.txt")
sigma_en_exc_4s2_22.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_502.txt")
sigma_en_exc_4s2_23.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_509.txt")
sigma_en_exc_4s2_24.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_515.txt")
sigma_en_exc_4s2_25.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_520.txt")
sigma_en_exc_4s2_26.readData("../src/CollisionalData/CrossSections/ArMetastables/4s2_5s_3d/Ar_e_EXCITATION_4s2_2_548.txt")


sigma_4s2_5s = [sigma_en_exc_4s2_11, sigma_en_exc_4s2_12, sigma_en_exc_4s2_13, sigma_en_exc_4s2_14,
                sigma_en_exc_4s2_15, sigma_en_exc_4s2_16, sigma_en_exc_4s2_17, sigma_en_exc_4s2_18, sigma_en_exc_4s2_19, 
                sigma_en_exc_4s2_20, sigma_en_exc_4s2_21, sigma_en_exc_4s2_22, sigma_en_exc_4s2_23, sigma_en_exc_4s2_24,
                sigma_en_exc_4s2_25, sigma_en_exc_4s2_26]



sigma_en_exc_4s3_11  = CS.CrossSection("Ar-e (4s'[1/2]0->3d[1/2]0)", potential = 2.346)
sigma_en_exc_4s3_12  = CS.CrossSection("Ar-e (4s'[1/2]0->3d[1/2]1)", potential = 2.358)
sigma_en_exc_4s3_13  = CS.CrossSection("Ar-e (4s'[1/2]0->3d[3/2]2)", potential = 2.377)
sigma_en_exc_4s3_14  = CS.CrossSection("Ar-e (4s'[1/2]0->3d[7/2]4)", potential = 2.426)
sigma_en_exc_4s3_15  = CS.CrossSection("Ar-e (4s'[1/2]0->5s[3/2]2)", potential = 2.441)
sigma_en_exc_4s3_16  = CS.CrossSection("Ar-e (4s'[1/2]0->3d[7/2]3)", potential = 2.442)
sigma_en_exc_4s3_17  = CS.CrossSection("Ar-e (4s'[1/2]0->5s[3/2]1)", potential = 2.456)
sigma_en_exc_4s3_18  = CS.CrossSection("Ar-e (4s'[1/2]0->3d[5/2]2)", potential = 2.478)
sigma_en_exc_4s3_19  = CS.CrossSection("Ar-e (4s'[1/2]0->3d[5/2]3)", potential = 2.489)
sigma_en_exc_4s3_20 = CS.CrossSection("Ar-e (4s'[1/2]0->3d[3/2]1)", potential = 2.504)
sigma_en_exc_4s3_21 = CS.CrossSection("Ar-e (4s'[1/2]0->5s'[1/2]0)", potential = 2.589)
sigma_en_exc_4s3_22 = CS.CrossSection("Ar-e (4s'[1/2]0->5s'[1/2]1)", potential = 2.607)
sigma_en_exc_4s3_23 = CS.CrossSection("Ar-e (4s'[1/2]0->3d'[5/2]2)", potential = 2.614)
sigma_en_exc_4s3_24 = CS.CrossSection("Ar-e (4s'[1/2]0->3d'[3/2]2)", potential = 2.620)
sigma_en_exc_4s3_25 = CS.CrossSection("Ar-e (4s'[1/2]0->3d'[5/2]3)", potential = 2.625)
sigma_en_exc_4s3_26 = CS.CrossSection("Ar-e (4s'[1/2]0->3d'[3/2]1)", potential = 2.653)


sigma_en_exc_4s3_11.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_346.txt")
sigma_en_exc_4s3_12.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_358.txt")
sigma_en_exc_4s3_13.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_377.txt")
sigma_en_exc_4s3_14.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_426.txt")
sigma_en_exc_4s3_15.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_441.txt")
sigma_en_exc_4s3_16.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_442.txt")
sigma_en_exc_4s3_17.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_456.txt")
sigma_en_exc_4s3_18.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_478.txt")
sigma_en_exc_4s3_19.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_489.txt")
sigma_en_exc_4s3_20.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_504.txt")
sigma_en_exc_4s3_21.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_589.txt")
sigma_en_exc_4s3_22.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_607.txt")
sigma_en_exc_4s3_23.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_614.txt")
sigma_en_exc_4s3_24.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_620.txt")
sigma_en_exc_4s3_25.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_625.txt")
sigma_en_exc_4s3_26.readData("../src/CollisionalData/CrossSections/ArMetastables/4s3_5s_3d/Ar_e_EXCITATION_4s3_2_653.txt")


sigma_4s3_5s = [sigma_en_exc_4s3_11, sigma_en_exc_4s3_12, sigma_en_exc_4s3_13, sigma_en_exc_4s3_14,
                sigma_en_exc_4s3_15, sigma_en_exc_4s3_16, sigma_en_exc_4s3_17, sigma_en_exc_4s3_18, sigma_en_exc_4s3_19, 
                sigma_en_exc_4s3_20, sigma_en_exc_4s3_21, sigma_en_exc_4s3_22, sigma_en_exc_4s3_23, sigma_en_exc_4s3_24,
                sigma_en_exc_4s3_25, sigma_en_exc_4s3_26]


sigma_en_exc_4s4_11  = CS.CrossSection("Ar-e (4s[3/2]1->3d[1/2]0)",  potential = 2.445)
sigma_en_exc_4s4_12  = CS.CrossSection("Ar-e (4s[3/2]1->3d[1/2]1)",  potential = 2.457)
sigma_en_exc_4s4_13  = CS.CrossSection("Ar-e (4s[3/2]1->3d[3/2]2)",  potential = 2.476)
sigma_en_exc_4s4_14  = CS.CrossSection("Ar-e (4s[3/2]1->3d[7/2]4)",  potential = 2.525)
sigma_en_exc_4s4_15  = CS.CrossSection("Ar-e (4s[3/2]1->5s[3/2]2)",  potential = 2.54)
sigma_en_exc_4s4_16  = CS.CrossSection("Ar-e (4s[3/2]1->3d[7/2]3)",  potential = 2.541)
sigma_en_exc_4s4_17  = CS.CrossSection("Ar-e (4s[3/2]1->5s[3/2]1)",  potential = 2.555)
sigma_en_exc_4s4_18  = CS.CrossSection("Ar-e (4s[3/2]1->3d[5/2]2)",  potential = 2.577)
sigma_en_exc_4s4_19  = CS.CrossSection("Ar-e (4s[3/2]1->3d[5/2]3)",  potential = 2.588)
sigma_en_exc_4s4_20  = CS.CrossSection("Ar-e (4s[3/2]1->3d[3/2]1)",  potential = 2.603)
sigma_en_exc_4s4_21  = CS.CrossSection("Ar-e (4s[3/2]1->5s'[1/2]0)", potential = 2.688)
sigma_en_exc_4s4_22  = CS.CrossSection("Ar-e (4s[3/2]1->5s'[1/2]1)", potential = 2.706)
sigma_en_exc_4s4_23  = CS.CrossSection("Ar-e (4s[3/2]1->3d'[5/2]2)", potential = 2.713)
sigma_en_exc_4s4_24  = CS.CrossSection("Ar-e (4s[3/2]1->3d'[3/2]2)", potential = 2.719)
sigma_en_exc_4s4_25  = CS.CrossSection("Ar-e (4s[3/2]1->3d'[5/2]3)", potential = 2.724)
sigma_en_exc_4s4_26  = CS.CrossSection("Ar-e (4s[3/2]1->3d'[3/2]1)", potential = 2.752)


sigma_en_exc_4s4_11.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_445.txt")
sigma_en_exc_4s4_12.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_457.txt")
sigma_en_exc_4s4_13.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_476.txt")
sigma_en_exc_4s4_14.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_525.txt")
sigma_en_exc_4s4_15.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_540.txt")
sigma_en_exc_4s4_16.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_541.txt")
sigma_en_exc_4s4_17.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_555.txt")
sigma_en_exc_4s4_18.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_577.txt")
sigma_en_exc_4s4_19.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_588.txt")
sigma_en_exc_4s4_20.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_603.txt")
sigma_en_exc_4s4_21.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_688.txt")
sigma_en_exc_4s4_22.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_706.txt")
sigma_en_exc_4s4_23.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_713.txt")
sigma_en_exc_4s4_24.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_719.txt")
sigma_en_exc_4s4_25.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_724.txt")
sigma_en_exc_4s4_26.readData("../src/CollisionalData/CrossSections/ArMetastables/4s4_5s_3d/Ar_e_EXCITATION_4s4_2_752.txt")


sigma_4s4_5s = [sigma_en_exc_4s4_11, sigma_en_exc_4s4_12, sigma_en_exc_4s4_13, sigma_en_exc_4s4_14,
                sigma_en_exc_4s4_15, sigma_en_exc_4s4_16, sigma_en_exc_4s4_17, sigma_en_exc_4s4_18, sigma_en_exc_4s4_19, 
                sigma_en_exc_4s4_20, sigma_en_exc_4s4_21, sigma_en_exc_4s4_22, sigma_en_exc_4s4_23, sigma_en_exc_4s4_24,
                sigma_en_exc_4s4_25, sigma_en_exc_4s4_26]

sigma_en_exc_4s5_11  = CS.CrossSection("Ar-e (4s[3/2]2->3d[1/2]0)",  potential = 2.520)
sigma_en_exc_4s5_12  = CS.CrossSection("Ar-e (4s[3/2]2->3d[1/2]1)",  potential = 2.532)
sigma_en_exc_4s5_13  = CS.CrossSection("Ar-e (4s[3/2]2->3d[3/2]2)",  potential = 2.551)
sigma_en_exc_4s5_14  = CS.CrossSection("Ar-e (4s[3/2]2->3d[7/2]4)",  potential = 2.600)
sigma_en_exc_4s5_15  = CS.CrossSection("Ar-e (4s[3/2]2->5s[3/2]2)",  potential = 2.615)
sigma_en_exc_4s5_16  = CS.CrossSection("Ar-e (4s[3/2]2->3d[7/2]3)",  potential = 2.616)
sigma_en_exc_4s5_17  = CS.CrossSection("Ar-e (4s[3/2]2->5s[3/2]1)",  potential = 2.630)
sigma_en_exc_4s5_18  = CS.CrossSection("Ar-e (4s[3/2]2->3d[5/2]2)",  potential = 2.652)
sigma_en_exc_4s5_19  = CS.CrossSection("Ar-e (4s[3/2]2->3d[5/2]3)",  potential = 2.663)
sigma_en_exc_4s5_20  = CS.CrossSection("Ar-e (4s[3/2]2->3d[3/2]1)",  potential = 2.678)
sigma_en_exc_4s5_21  = CS.CrossSection("Ar-e (4s[3/2]2->5s'[1/2]0)", potential = 2.763)
sigma_en_exc_4s5_22  = CS.CrossSection("Ar-e (4s[3/2]2->5s'[1/2]1)", potential = 2.781)
sigma_en_exc_4s5_23  = CS.CrossSection("Ar-e (4s[3/2]2->3d'[5/2]2)", potential = 2.788)
sigma_en_exc_4s5_24  = CS.CrossSection("Ar-e (4s[3/2]2->3d'[3/2]2)", potential = 2.794)
sigma_en_exc_4s5_25  = CS.CrossSection("Ar-e (4s[3/2]2->3d'[5/2]3)", potential = 2.799)
sigma_en_exc_4s5_26  = CS.CrossSection("Ar-e (4s[3/2]2->3d'[3/2]1)", potential = 2.827)


sigma_en_exc_4s5_11.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_520.txt")
sigma_en_exc_4s5_12.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_532.txt")
sigma_en_exc_4s5_13.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_551.txt")
sigma_en_exc_4s5_14.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_600.txt")
sigma_en_exc_4s5_15.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_615.txt")
sigma_en_exc_4s5_16.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_616.txt")
sigma_en_exc_4s5_17.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_630.txt")
sigma_en_exc_4s5_18.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_652.txt")
sigma_en_exc_4s5_19.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_663.txt")
sigma_en_exc_4s5_20.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_678.txt")
sigma_en_exc_4s5_21.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_763.txt")
sigma_en_exc_4s5_22.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_781.txt")
sigma_en_exc_4s5_23.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_788.txt")
sigma_en_exc_4s5_24.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_794.txt")
sigma_en_exc_4s5_25.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_799.txt")
sigma_en_exc_4s5_26.readData("../src/CollisionalData/CrossSections/ArMetastables/4s5_5s_3d/Ar_e_EXCITATION_4s5_2_827.txt")


sigma_4s5_5s = [sigma_en_exc_4s5_11, sigma_en_exc_4s5_12, sigma_en_exc_4s5_13, sigma_en_exc_4s5_14,
                sigma_en_exc_4s5_15, sigma_en_exc_4s5_16, sigma_en_exc_4s5_17, sigma_en_exc_4s5_18, sigma_en_exc_4s5_19, 
                sigma_en_exc_4s5_20, sigma_en_exc_4s5_21, sigma_en_exc_4s5_22, sigma_en_exc_4s5_23, sigma_en_exc_4s5_24,
                sigma_en_exc_4s5_25, sigma_en_exc_4s5_26]



# Ground to 4p, 3d and 5s
sigma_en_exc_4p      = CS.CrossSection("Ar-e (4p)", potential = 13.00, category='EXCITATION',
                                      param='E = %.2f'%(13.00),
                                      species = ['e', 'Ar'], process='E + Ar -> Ar_*(13.00 eV) + E, Excitation',
                                      updated=day)
sigma_en_exc_3d_5s   = CS.CrossSection("Ar-e (3d-5s)", potential = 14.00, category='EXCITATION',
                                      param='E = %.2f'%(14.00),
                                      species = ['e', 'Ar'], process='E + Ar -> Ar_*(14.00 eV) + E, Excitation',
                                      updated=day)

sigma_en_exc_4p.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_13.txt")
sigma_en_exc_3d_5s.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATION_14.txt")


# Ground to 4p, 3d and 5s
sigma_en_exc_4p_casc      = CS.CrossSection("Ar-e casc. (4p)", potential = 13.00, category='EXCITATION',
                                      param='E = %.2f'%(13.00),
                                      species = ['e', 'Ar'], process='E + Ar -> Ar_*(13.00 eV) + E, Excitation',
                                      updated=day)
sigma_en_exc_3d_5s_casc   = CS.CrossSection("Ar-e casc. (3d-5s)", potential = 14.00, category='EXCITATION',
                                      param='E = %.2f'%(14.00),
                                      species = ['e', 'Ar'], process='E + Ar -> Ar_*(14.00 eV) + E, Excitation',
                                      updated=day)

sigma_en_exc_4p_casc.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATIONCASCADE_13.txt", units='a2')
sigma_en_exc_3d_5s_casc.readData("../src/CollisionalData/CrossSections/ArMetastables/Ar_e_EXCITATIONCASCADE_14.txt", units='a2')



# sigma_en_iz    = CS.CrossSection("Ar-e (Ioniz.)", potential = 15.76)
# sigma_ee_el    = CS.CrossSection("e-e", mechanism='e-e', density = 1e18, temperature = 3)
# sigma_ei_el    = CS.CrossSection("e-i", mechanism='e-e', density = 2.974e17, temperature = 3)


# Read the data
sigma_en_el.readData("../src/CollisionalData/CrossSections/ArReducedSet/Ar_e_ELASTIC_CROSS_SECTION.txt")



# sigma_en_iz.readData("../src/CollisionalData/CrossSections/ArReducedSet/Ar_e_IONIZATION_CROSS_SECTION.txt")

# %%
# %matplotlib notebook

# %% [markdown]
# # Ar + e$^- \rightarrow$ Ar$^*$ + e$^-$

# %%
f, ax = plt.subplots()

import scipy.constants as phy_const

for sigma in sigma_Gr_4s:
    sigma.plotSigma(ax)
    

for sigma in sigma_Gr_4s_casc:
    sigma.plotSigma(ax)
    

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-19])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('Ground to 4s')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# ## Sum of excitation

# %%
from scipy import interpolate

from datetime import date
today = date.today()

# mm/dd/y
day = today.strftime("%m/%d/%y")

sigma_en_exc_4s_sum = CS.CrossSection("Ar-e (4s)", potential = 11.55, category='EXCITATION',
                                      param='E = %.2f'%(11.55),
                                      species = ['e', 'Ar'], process='E + Ar -> Ar_4s(11.55 eV) + E, Excitation',
                                      updated=day)

sigma_en_exc_4s_sum.Energy = 10**(np.linspace(1,2.5,500))
sigma_en_exc_4s_sum.Sigma = 1e-20*np.zeros_like(sigma_en_exc_4s_sum.Energy)

for sigma in sigma_Gr_4s: 
    sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
    sigma_en_exc_4s_sum.Sigma += 10**sigma_interp(np.log10(sigma_en_exc_4s_sum.Energy))
# Out:
# /var/folders/dm/fpq2vxz16_9577l0qt42tjqw0000gn/T/ipykernel_56009/1300240662.py:18: RuntimeWarning: divide by zero encountered in log10
#   sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))

# %%
sigma_en_exc_4s_sum_casc = CS.CrossSection("Ar-e (4s)", potential = 11.55, category='EXCITATION',
                                      param='E = %.2f'%(11.55),
                                      species = ['e', 'Ar'], process='E + Ar -> Ar_4s(11.55 eV) + E, Excitation',
                                      updated=day)

sigma_en_exc_4s_sum_casc.Energy = 10**(np.linspace(1,2.5,200))
sigma_en_exc_4s_sum_casc.Sigma = 1e-20*np.zeros_like(sigma_en_exc_4s_sum_casc.Energy)

for sigma in sigma_Gr_4s_casc: 
    sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
    sigma_en_exc_4s_sum_casc.Sigma += 10**sigma_interp(np.log10(sigma_en_exc_4s_sum_casc.Energy))

# %%
f, ax = plt.subplots()

import scipy.constants as phy_const

for sigma in sigma_Gr_4s:
    sigma.plotSigma(ax)
    
sigma_en_exc_4s_sum.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-19])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('Ground to 4s')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# ## Sum of de-excitation

# %%
# Ground to 4s

sigma_en_deexc_4s_sum = CS.CrossSection("Ar-e de-ex (4s)", potential = -11.55, category='EXCITATION',
                                      param='E = %.2f'%(-11.55),
                                      species = ['e', 'Ar_4s'], process='E + Ar_4s -> Ar + E, Excitation',
                                      updated=day)

sigma_en_deexc_4s_sum.Energy = 10**(np.linspace(-1,2.5,500))
sigma_en_deexc_4s_sum.Sigma  = 1e-20*np.zeros_like(sigma_en_deexc_4s_sum.Energy)

statistical_weights = [5., 3., 1., 3.]

for i_sigma, sigma in enumerate(sigma_Gr_4s): 
    sigma_interp    = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
    weighted_sigma_i  = 10**sigma_interp(np.log10(sigma_en_deexc_4s_sum.Energy))/statistical_weights[i_sigma]
    weighted_sigma_iEnergy = weighted_sigma_i*sigma_en_deexc_4s_sum.Energy
    Energy_i          = sigma_en_deexc_4s_sum.Energy-sigma.potential

    sigma_interp_2    = interpolate.interp1d(np.log10(Energy_i), np.log10(weighted_sigma_i),bounds_error=False,fill_value=(np.log10(weighted_sigma_i[0]),np.log10(weighted_sigma_i[-1])))

    sigma_en_deexc_4s_sum.Sigma += 10**sigma_interp_2(np.log10(sigma_en_deexc_4s_sum.Energy))/sigma_en_deexc_4s_sum.Energy


    
    print(sigma.name, "statistical weight: ", statistical_weights[i_sigma], "potential = ", sigma.potential)
# Out:
# Ar-e (4s[3/2]2) statistical weight:  5.0 potential =  11.549
# Ar-e (4s[3/2]1) statistical weight:  3.0 potential =  11.624
# Ar-e (4s'[1/2]0) statistical weight:  1.0 potential =  11.723
# Ar-e (4s'[1/2]1) statistical weight:  3.0 potential =  11.828
# /var/folders/dm/fpq2vxz16_9577l0qt42tjqw0000gn/T/ipykernel_56009/3272461376.py:14: RuntimeWarning: divide by zero encountered in log10
#   sigma_interp    = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
# /var/folders/dm/fpq2vxz16_9577l0qt42tjqw0000gn/T/ipykernel_56009/3272461376.py:19: RuntimeWarning: invalid value encountered in log10
#   sigma_interp_2    = interpolate.interp1d(np.log10(Energy_i), np.log10(weighted_sigma_i),bounds_error=False,fill_value=(np.log10(weighted_sigma_i[0]),np.log10(weighted_sigma_i[-1])))
# ...

# %%
f, ax = plt.subplots()

import scipy.constants as phy_const

    
sigma_en_deexc_4s_sum.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-19])
ax.set_xlim([1e-1, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s to ground')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
# Plot the data
f, ax = plt.subplots()

import scipy.constants as phy_const


sigma_en_exc_4s_sum.plotSigma(ax)
sigma_en_exc_4p.plotSigma(ax)
sigma_en_exc_3d_5s.plotSigma(ax)

sigma_en_exc_4p_casc.plotSigma(ax)
sigma_en_exc_3d_5s_casc.plotSigma(ax)


ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-19])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('Ground to 4s, 4p, 3d, 5s')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# # Ar$^*$ + e$^- \rightarrow$ Ar$^{**}$ + e$^-$

# %% [markdown]
# ## 4s $\rightarrow$ 4p

# %%
f, ax = plt.subplots()

import scipy.constants as phy_const

for sigma in sigma_4s2_4p:
    sigma.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-18])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s -> 4p')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
f, ax = plt.subplots()

import scipy.constants as phy_const

for sigma in sigma_4s3_4p:
    sigma.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-18])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s -> 4p')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
f, ax = plt.subplots()

import scipy.constants as phy_const

for sigma in sigma_4s4_4p:
    sigma.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-18])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s -> 4p')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
f, ax = plt.subplots()

import scipy.constants as phy_const

for sigma in sigma_4s5_4p:
    sigma.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-18])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s -> 4p')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# ### Sum of excitation from 4s

# %%
sigma_exc_4s2_4p_sum = CS.CrossSection("Ar(4s2)-e (4p)", potential = 1.45)

sigma_exc_4s2_4p_sum.Energy = 10**(np.linspace(0,2.5,500))
sigma_exc_4s2_4p_sum.Sigma = 1e-20*np.zeros_like(sigma_exc_4s2_4p_sum.Energy)

for sigma in sigma_4s2_4p: 
    sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
    sigma_exc_4s2_4p_sum.Sigma += 10**sigma_interp(np.log10(sigma_exc_4s2_4p_sum.Energy))

sigma_exc_4s3_4p_sum = CS.CrossSection("Ar(4s3)-e (4p)", potential = 1.45)

sigma_exc_4s3_4p_sum.Energy = 10**(np.linspace(0,2.5,500))
sigma_exc_4s3_4p_sum.Sigma = 1e-20*np.zeros_like(sigma_exc_4s3_4p_sum.Energy)

for sigma in sigma_4s3_4p: 
    sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
    sigma_exc_4s3_4p_sum.Sigma += 10**sigma_interp(np.log10(sigma_exc_4s3_4p_sum.Energy))


sigma_exc_4s4_4p_sum = CS.CrossSection("Ar(4s4)-e (4p)", potential = 1.45)

sigma_exc_4s4_4p_sum.Energy = 10**(np.linspace(0,2.5,500))
sigma_exc_4s4_4p_sum.Sigma = 1e-20*np.zeros_like(sigma_exc_4s4_4p_sum.Energy)

for sigma in sigma_4s4_4p: 
    sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
    sigma_exc_4s4_4p_sum.Sigma += 10**sigma_interp(np.log10(sigma_exc_4s4_4p_sum.Energy))


sigma_exc_4s5_4p_sum = CS.CrossSection("Ar(4s5)-e (4p)", potential = 1.45)

sigma_exc_4s5_4p_sum.Energy = 10**(np.linspace(0,2.5,500))
sigma_exc_4s5_4p_sum.Sigma = 1e-20*np.zeros_like(sigma_exc_4s5_4p_sum.Energy)

for sigma in sigma_4s5_4p: 
    sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
    sigma_exc_4s5_4p_sum.Sigma += 10**sigma_interp(np.log10(sigma_exc_4s5_4p_sum.Energy))

    
sigma_exc_4s_4p_sum = CS.CrossSection("Ar(4s)-e (4p)", potential = 1.45, category='EXCITATION',
                                      param='E = %.2f'%(1.45),
                                      species = ['e', 'Ar_4s'], process='E + Ar_4s -> Ar_*(13.00 eV) + E, Excitation',
                                      updated=day)
sigma_exc_4s_4p_sum.Energy = 10**(np.linspace(0,2.5,500))
sigma_exc_4s_4p_sum.Sigma = 1e-20*np.zeros_like(sigma_exc_4s_4p_sum.Energy)
sigma_exc_4s_4p_sum.Sigma = sigma_exc_4s2_4p_sum.Sigma+sigma_exc_4s3_4p_sum.Sigma+sigma_exc_4s4_4p_sum.Sigma+sigma_exc_4s5_4p_sum.Sigma
# Out:
# /var/folders/dm/fpq2vxz16_9577l0qt42tjqw0000gn/T/ipykernel_56009/1625449443.py:7: RuntimeWarning: divide by zero encountered in log10
#   sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
# /var/folders/dm/fpq2vxz16_9577l0qt42tjqw0000gn/T/ipykernel_56009/1625449443.py:16: RuntimeWarning: divide by zero encountered in log10
#   sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
# /var/folders/dm/fpq2vxz16_9577l0qt42tjqw0000gn/T/ipykernel_56009/1625449443.py:26: RuntimeWarning: divide by zero encountered in log10
#   sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
# ...

# %%
f, ax = plt.subplots()

sigma_exc_4s2_4p_sum.plotSigma(ax)
sigma_exc_4s3_4p_sum.plotSigma(ax)
sigma_exc_4s4_4p_sum.plotSigma(ax)
sigma_exc_4s5_4p_sum.plotSigma(ax)

sigma_exc_4s_4p_sum.plotSigma(ax)
sigma_exc_4s_4p_sum_casc.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-17])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s -> 4p')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# ## 4s $\rightarrow$ 5s and 3d

# %%
f, ax = plt.subplots()

import scipy.constants as phy_const

for sigma in sigma_4s2_5s:
    sigma.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-18])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s2 -> 5s and 3d')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f, ax = plt.subplots()

import scipy.constants as phy_const

for sigma in sigma_4s3_5s:
    sigma.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-18])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s3 -> 5s and 3d')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f, ax = plt.subplots()

import scipy.constants as phy_const

for sigma in sigma_4s4_5s:
    sigma.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-18])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s4 -> 5s and 3d')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f, ax = plt.subplots()

import scipy.constants as phy_const

for sigma in sigma_4s5_5s:
    sigma.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-18])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s5 -> 5s and 3d')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Sum of excitation from 4s to 5s and 3d

# %%
sigma_exc_4s2_sum = CS.CrossSection("Ar(4s2)-e (5s-3d)", potential = 2.45)

sigma_exc_4s2_sum.Energy = 10**(np.linspace(0,2.5,500))
sigma_exc_4s2_sum.Sigma = 1e-20*np.zeros_like(sigma_exc_4s2_sum.Energy)

for sigma in sigma_4s2_5s: 
    sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
    sigma_exc_4s2_sum.Sigma += 10**sigma_interp(np.log10(sigma_exc_4s2_sum.Energy))

sigma_exc_4s3_sum = CS.CrossSection("Ar(4s3)-e (5s-3d)", potential = 2.45)

sigma_exc_4s3_sum.Energy = 10**(np.linspace(0,2.5,500))
sigma_exc_4s3_sum.Sigma = 1e-20*np.zeros_like(sigma_exc_4s3_sum.Energy)

for sigma in sigma_4s3_5s: 
    sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
    sigma_exc_4s3_sum.Sigma += 10**sigma_interp(np.log10(sigma_exc_4s3_sum.Energy))


sigma_exc_4s4_sum = CS.CrossSection("Ar(4s4)-e (5s-3d)", potential = 2.45)

sigma_exc_4s4_sum.Energy = 10**(np.linspace(0,2.5,500))
sigma_exc_4s4_sum.Sigma = 1e-20*np.zeros_like(sigma_exc_4s4_sum.Energy)

for sigma in sigma_4s4_5s: 
    sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
    sigma_exc_4s4_sum.Sigma += 10**sigma_interp(np.log10(sigma_exc_4s4_sum.Energy))


sigma_exc_4s5_sum = CS.CrossSection("Ar(4s5)-e (5s-3d)", potential = 2.45)

sigma_exc_4s5_sum.Energy = 10**(np.linspace(0,2.5,500))
sigma_exc_4s5_sum.Sigma = 1e-20*np.zeros_like(sigma_exc_4s5_sum.Energy)

for sigma in sigma_4s5_5s: 
    sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
    sigma_exc_4s5_sum.Sigma += 10**sigma_interp(np.log10(sigma_exc_4s5_sum.Energy))

    
sigma_exc_4s_5s_sum = CS.CrossSection("Ar(4s)-e (5s-3d)", potential = 2.45, category='EXCITATION',
                                      param='E = %.2f'%(2.45),
                                      species = ['e', 'Ar_4s'], process='E + Ar_4s -> Ar_*(14.00 eV) + E, Excitation',
                                      updated=day)
sigma_exc_4s_5s_sum.Energy = 10**(np.linspace(0,2.5,500))
sigma_exc_4s_5s_sum.Sigma = 1e-20*np.zeros_like(sigma_exc_4s3_sum.Energy)
sigma_exc_4s_5s_sum.Sigma = sigma_exc_4s2_sum.Sigma+sigma_exc_4s3_sum.Sigma+sigma_exc_4s4_sum.Sigma+sigma_exc_4s5_sum.Sigma
# Out:
# /var/folders/dm/fpq2vxz16_9577l0qt42tjqw0000gn/T/ipykernel_1663/4070158281.py:7: RuntimeWarning: divide by zero encountered in log10
#   sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
# /var/folders/dm/fpq2vxz16_9577l0qt42tjqw0000gn/T/ipykernel_1663/4070158281.py:16: RuntimeWarning: divide by zero encountered in log10
#   sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
# /var/folders/dm/fpq2vxz16_9577l0qt42tjqw0000gn/T/ipykernel_1663/4070158281.py:26: RuntimeWarning: divide by zero encountered in log10
#   sigma_interp               = interpolate.interp1d(np.log10(sigma.Energy), np.log10(sigma.Sigma),bounds_error=False,fill_value=(np.log10(sigma.Sigma[0]),np.log10(sigma.Sigma[-1])))
# ...

# %%
f, ax = plt.subplots()

sigma_exc_4s2_sum.plotSigma(ax)
sigma_exc_4s3_sum.plotSigma(ax)
sigma_exc_4s4_sum.plotSigma(ax)
sigma_exc_4s5_sum.plotSigma(ax)

sigma_exc_4s_5s_sum.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-17])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s -> 5s, 3d')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Total stepwise excitation

# %%
sigma_exc_4s_4p5s3d_sum        = CS.CrossSection("Ar(4s)-e (4p-5s-3d)", potential = 1.45, category='EXCITATION',
                                      param='E = %.2f'%(1.45),
                                      species = ['e', 'Ar_4s'], process='E + Ar_4s -> Ar_*(13.00 eV) + E, Excitation',
                                      updated=day)
sigma_exc_4s_4p5s3d_sum.Energy = 10**(np.linspace(0,2.5,500))
sigma_exc_4s_4p5s3d_sum.Sigma  = 1e-20*np.zeros_like(sigma_exc_4s3_sum.Energy)
sigma_exc_4s_4p5s3d_sum.Sigma  = sigma_exc_4s_4p_sum.Sigma+sigma_exc_4s_5s_sum.Sigma

# %%
f, ax = plt.subplots()

sigma_exc_4s2_4p_sum.plotSigma(ax)
sigma_exc_4s3_4p_sum.plotSigma(ax)
sigma_exc_4s4_4p_sum.plotSigma(ax)
sigma_exc_4s5_4p_sum.plotSigma(ax)

sigma_exc_4s_4p_sum.plotSigma(ax)

sigma_exc_4s2_sum.plotSigma(ax)
sigma_exc_4s3_sum.plotSigma(ax)
sigma_exc_4s4_sum.plotSigma(ax)
sigma_exc_4s5_sum.plotSigma(ax)

sigma_exc_4s_5s_sum.plotSigma(ax)

sigma_exc_4s_4p5s3d_sum.Color = 'k'
sigma_exc_4s_4p5s3d_sum.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-25, 1e-17])
ax.set_xlim([1e0, 1000])
plt.legend(loc = 'best', fontsize = 10)
plt.title('4s -> 5s, 3d')

ax.grid(True)

#plt.savefig("./crossSections_elec.pdf", bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Make LPPiC file

# %%
# e-Ar collisions

for coll in [sigma_en_exc_4s_sum,sigma_en_exc_4p, sigma_en_exc_3d_5s]:
    print()
    print(coll.category)
    print(' %.6e' % coll.potential)
    print('SPECIES : ', " / ".join(coll.species))
    print('PROCESS: ', coll.process)
    print('PARAM.:  ', coll.param)
    print('COMMENT: ', coll.comment)
    print('UPDATED: ', coll.updated)
    print('COLUMNS: Energy (eV) | Cross section (m2)')
# Out:
# EXCITATION
#  1.155000e+01
# SPECIES :  e / Ar
# PROCESS:  E + Ar -> Ar_4s(11.55 eV) + E, Excitation
# PARAM.:   E = 11.55
# COMMENT:  None
# UPDATED:  03/05/24
# COLUMNS: Energy (eV) | Cross section (m2)
#
# EXCITATION
#  1.300000e+01
# SPECIES :  e / Ar
# PROCESS:  E + Ar -> Ar_*(13.00 eV) + E, Excitation
# PARAM.:   E = 13.00
# COMMENT:  None
# UPDATED:  03/05/24
# COLUMNS: Energy (eV) | Cross section (m2)
#
# EXCITATION
#  1.400000e+01
# SPECIES :  e / Ar
# PROCESS:  E + Ar -> Ar_*(14.00 eV) + E, Excitation
# PARAM.:   E = 14.00
# COMMENT:  None
# UPDATED:  03/05/24
# COLUMNS: Energy (eV) | Cross section (m2)

# %%
original_stdout = sys.stdout # Save a reference to the original standard output

FileName = './e_Ar_test.txt'

with open(FileName, 'w') as f:
    
    sys.stdout = f # Change the standard output to the file we created.

    print('**************************************************************************************************************\n')

    sys.stdout = original_stdout
    
    for coll in [sigma_en_exc_4s_sum,sigma_en_exc_4p, sigma_en_exc_3d_5s]:
        
        sys.stdout = f
        print()
        print(coll.category)
        if(coll.category=="ELASTIC"):
            print(coll.species[1])
        if(coll.category=="EXCITATION"):
            print(coll.species[1]+" -> "+coll.species[1]+"*("+str(coll.potential)+"eV)")
        if(coll.category=="IONIZATION"):
            print(coll.species[1]+" -> "+coll.species[1]+"^+")
        print(' %.6e' % coll.potential)
        print('SPECIES : ', " / ".join(coll.species))
        print('PROCESS: ', coll.process)
        print('PARAM.:  ', coll.param)
        print('COMMENT: ', coll.comment)
        print('UPDATED: ', coll.updated)
        print('COLUMNS: Energy (eV) | Cross section (m2)')
        print('-----------------------------')
        for i, energy in enumerate(coll.Energy):
            print(' %.6e    %.6e' % (energy, coll.Sigma[i]))
        print('-----------------------------')

        sys.stdout = original_stdout # Reset the standard output to its original value
        sys.stdout = f # Change the standard output to the file we created.

    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')

    sys.stdout = original_stdout

# %%
for coll in [sigma_en_exc_4s_sum,sigma_en_exc_4p, sigma_en_exc_3d_5s]:
    print()
    print(coll.category)
    print(' %.6e' % coll.potential)
    print('SPECIES : ', " / ".join(coll.species))
    print('PROCESS: ', coll.process)
    print('PARAM.:  ', coll.param)
    print('COMMENT: ', coll.comment)
    print('UPDATED: ', coll.updated)
    print('COLUMNS: Energy (eV) | Cross section (m2)')

# %%
original_stdout = sys.stdout # Save a reference to the original standard output

FileName = './e_Ar_test.txt'

with open(FileName, 'w') as f:
    
    sys.stdout = f # Change the standard output to the file we created.

    print('**************************************************************************************************************\n')

    sys.stdout = original_stdout
    
    for coll in [sigma_en_exc_4s_sum,sigma_en_exc_4p, sigma_en_exc_3d_5s]:
        
        sys.stdout = f
        print()
        print(coll.category)
        if(coll.category=="ELASTIC"):
            print(coll.species[1])
        if(coll.category=="EXCITATION"):
            print(coll.species[1]+" -> "+coll.species[1]+"*("+str(coll.potential)+"eV)")
        if(coll.category=="IONIZATION"):
            print(coll.species[1]+" -> "+coll.species[1]+"^+")
        print(' %.6e' % coll.potential)
        print('SPECIES : ', " / ".join(coll.species))
        print('PROCESS: ', coll.process)
        print('PARAM.:  ', coll.param)
        print('COMMENT: ', coll.comment)
        print('UPDATED: ', coll.updated)
        print('COLUMNS: Energy (eV) | Cross section (m2)')
        print('-----------------------------')
        for i, energy in enumerate(coll.Energy):
            print(' %.6e    %.6e' % (energy, coll.Sigma[i]))
        print('-----------------------------')

        sys.stdout = original_stdout # Reset the standard output to its original value
        sys.stdout = f # Change the standard output to the file we created.

    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')

    sys.stdout = original_stdout

# %%
for coll in [sigma_exc_4s_4p_sum, sigma_exc_4s_5s_sum, sigma_en_deexc_4s_sum]:
    print()
    print(coll.category)
    print(' %.6e' % coll.potential)
    print('SPECIES : ', " / ".join(coll.species))
    print('PROCESS: ', coll.process)
    print('PARAM.:  ', coll.param)
    print('COMMENT: ', coll.comment)
    print('UPDATED: ', coll.updated)
    print('COLUMNS: Energy (eV) | Cross section (m2)')
# Out:
# EXCITATION
#  1.450000e+00
# SPECIES :  e / Ar_4s
# PROCESS:  E + Ar_4s -> Ar_*(13.00 eV) + E, Excitation
# PARAM.:   E = 1.45
# COMMENT:  None
# UPDATED:  03/05/24
# COLUMNS: Energy (eV) | Cross section (m2)
#
# EXCITATION
#  2.450000e+00
# SPECIES :  e / Ar_4s
# PROCESS:  E + Ar_4s -> Ar_*(14.00 eV) + E, Excitation
# PARAM.:   E = 2.45
# COMMENT:  None
# UPDATED:  03/05/24
# COLUMNS: Energy (eV) | Cross section (m2)
#
# EXCITATION
#  -1.155000e+01
# SPECIES :  e / Ar_4s
# PROCESS:  E + Ar_4s -> Ar + E, Excitation
# PARAM.:   E = -11.55
# COMMENT:  None
# UPDATED:  03/05/24
# COLUMNS: Energy (eV) | Cross section (m2)

# %%
original_stdout = sys.stdout # Save a reference to the original standard output

FileName = './e_Ar_4s.txt'

with open(FileName, 'w') as f:
    
    sys.stdout = f # Change the standard output to the file we created.

    print('**************************************************************************************************************\n')

    sys.stdout = original_stdout
    
    for coll in [sigma_exc_4s_4p_sum, sigma_exc_4s_5s_sum, sigma_en_deexc_4s_sum]:
        
        sys.stdout = f
        print()
        print(coll.category)
        if(coll.category=="ELASTIC"):
            print(coll.species[1])
        if(coll.category=="EXCITATION"):
            print(coll.species[1]+" -> "+coll.species[1]+"*("+str(coll.potential)+"eV)")
        if(coll.category=="IONIZATION"):
            print(coll.species[1]+" -> "+coll.species[1]+"^+")
        print(' %.6e' % coll.potential)
        print('SPECIES : ', " / ".join(coll.species))
        print('PROCESS: ', coll.process)
        print('PARAM.:  ', coll.param)
        print('COMMENT: ', coll.comment)
        print('UPDATED: ', coll.updated)
        print('COLUMNS: Energy (eV) | Cross section (m2)')
        print('-----------------------------')
        for i, energy in enumerate(coll.Energy):
            print(' %.6e    %.6e' % (energy, coll.Sigma[i]))
        print('-----------------------------')

        sys.stdout = original_stdout # Reset the standard output to its original value
        sys.stdout = f # Change the standard output to the file we created.

    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')

    sys.stdout = original_stdout

# %% [markdown]
# # Plot the average rate integrated over a Maxwellian

# %% [markdown]
# We compute the rate as:
#
# $$ K = \left(\frac{m_e}{2\pi k_B T_e} \right)^{3/2} \int^\infty_0 4\pi c_e^2\sigma \exp\left(-\frac{m_e  c_e^2}{2 k_B T_e}\right) dc_{e}. $$

# %%
# Compute the rates
sigma_en_el.computeRate()
sigma_ee_el.computeRate()
sigma_en_exc_1.computeRate()
sigma_en_exc_2.computeRate()
sigma_en_exc_3.computeRate()
sigma_en_iz.computeRate()



# Plot the data
f, ax = plt.subplots()

sigma_en_el.plotRate(ax)
sigma_ee_el.plotRate(ax)
sigma_en_exc_1.plotRate(ax)
sigma_en_exc_2.plotRate(ax)
sigma_en_exc_3.plotRate(ax)
sigma_en_iz.plotRate(ax)

ax.set_ylabel(r'$K$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_e$ [eV]')
ax.set_yscale('log')
ax.set_xlim([1.5, 10])
#ax.set_ylim([1e-16, 1e-12])
plt.legend(loc = 'best', fontsize = 10)
ax.grid(True)

#plt.savefig("./AverageRate_elec.pdf", bbox_inches='tight')



plt.show()

# %% [markdown]
# ### Plot the $\Omega^{(1,1)}$
#
# We define the integral as:
#
# $$\Omega^{(l,r)} = \left(\frac{k_B T_e}{2\pi m_e}\right)^{1/2}\int^\infty_0 \xi^{2r+3}\exp(-\xi^2)Q^{(l)}(\xi) d\xi.$$

# %%
# Compute the rates
sigma_en_el.computeOmega11()
sigma_en_exc_1.computeOmega11()
sigma_en_exc_2.computeOmega11()
sigma_en_exc_3.computeOmega11()
#sigma_en_exc_4.computeOmega11()



# Plot the data
f, ax = plt.subplots()

sigma_en_el.plotOmega11(ax)
sigma_en_exc_1.plotOmega11(ax)
sigma_en_exc_2.plotOmega11(ax)
sigma_en_exc_3.plotOmega11(ax)
#sigma_en_exc_4.plotOmega11(ax)

ax.set_ylabel(r'$\Omega^{(1,1)}$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_e$ [eV]')
ax.set_yscale('log')
ax.set_xlim([2, 10])
#ax.set_ylim([1e-16, 1e-12])
plt.legend(loc = 'best', fontsize = 10)
ax.grid(True)
#plt.savefig("/Users/alaguna/Documents/16_PostDoc/77_MomentMethodsPaper/Figures/Omega11_elec.pdf", bbox_inches='tight')



plt.show()

# %%
# Compute the rates
sigma_en_el.computeOmega12()
sigma_en_exc_1.computeOmega12()
sigma_en_exc_2.computeOmega12()
sigma_en_exc_3.computeOmega12()
#sigma_en_exc_4.computeOmega12()



# Plot the data
f, ax = plt.subplots()

sigma_en_el.plotOmega12(ax)
sigma_en_exc_1.plotOmega12(ax)
sigma_en_exc_2.plotOmega12(ax)
sigma_en_exc_3.plotOmega12(ax)
#sigma_en_exc_4.plotOmega12(ax)

ax.set_ylabel(r'$\Omega^{(1,2)}$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_e$ [eV]')
ax.set_yscale('log')
ax.set_xlim([2, 10])
#ax.set_ylim([1e-16, 1e-12])
plt.legend(loc = 'best', fontsize = 10)
ax.grid(True)
#plt.savefig("/Users/alaguna/Documents/16_PostDoc/77_MomentMethodsPaper/Figures/Omega12_elec.pdf", bbox_inches='tight')



plt.show()

# %%
# Compute the rates
sigma_en_el.computeOmega13()
sigma_en_exc_1.computeOmega13()
sigma_en_exc_2.computeOmega13()
sigma_en_exc_3.computeOmega13()
#sigma_en_exc_4.computeOmega13()



# Plot the data
f, ax = plt.subplots()

sigma_en_el.plotOmega13(ax)
sigma_en_exc_1.plotOmega13(ax)
sigma_en_exc_2.plotOmega13(ax)
sigma_en_exc_3.plotOmega13(ax)
#sigma_en_exc_4.plotOmega13(ax)

ax.set_ylabel(r'$\Omega^{(1,3)}$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_e$ [eV]')
ax.set_yscale('log')
ax.set_xlim([2, 10])
#ax.set_ylim([1e-16, 1e-12])
plt.legend(loc = 'best', fontsize = 10)
ax.grid(True)
#plt.savefig("/Users/alaguna/Documents/16_PostDoc/77_MomentMethodsPaper/Figures/Omega11_elec.pdf", bbox_inches='tight')



plt.show()

# %%
# Compute the rates
sigma_en_el.computeOmega14()
sigma_en_exc_1.computeOmega14()
sigma_en_exc_2.computeOmega14()
sigma_en_exc_3.computeOmega14()
#sigma_en_exc_4.computeOmega14()

# Plot the data
f, ax = plt.subplots()

sigma_en_el.plotOmega14(ax)
sigma_en_exc_1.plotOmega14(ax)
sigma_en_exc_2.plotOmega14(ax)
sigma_en_exc_3.plotOmega14(ax)
#sigma_en_exc_4.plotOmega14(ax)

ax.set_ylabel(r'$\Omega^{(1,4)}$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_e$ [eV]')
ax.set_yscale('log')
ax.set_xlim([2, 10])
#ax.set_ylim([1e-16, 1e-12])
plt.legend(loc = 'best', fontsize = 10)
ax.grid(True)
#plt.savefig("/Users/alaguna/Documents/16_PostDoc/77_MomentMethodsPaper/Figures/Omega11_elec.pdf", bbox_inches='tight')



plt.show()

# %%
# Compute the rates
sigma_en_el.computeOmega22()
sigma_ee_el.computeOmega22()
sigma_en_exc_1.computeOmega22()
sigma_en_exc_2.computeOmega22()
sigma_en_exc_3.computeOmega22()
#sigma_en_exc_4.computeOmega22()



# Plot the data
f, ax = plt.subplots()

sigma_en_el.plotOmega22(ax)
sigma_ee_el.plotOmega22(ax)
sigma_en_exc_1.plotOmega22(ax)
sigma_en_exc_2.plotOmega22(ax)
sigma_en_exc_3.plotOmega22(ax)
#sigma_en_exc_4.plotOmega22(ax)

ax.set_ylabel(r'$\Omega^{(2,2)}$ $[m^{2}]$')
ax.set_xlabel(r'$T_e$ [eV]')
ax.set_yscale('log')
ax.set_xlim([2, 10])
#ax.set_ylim([1e-16, 1e-12])
plt.legend(loc = 'best', fontsize = 10)

ax.grid(True)

plt.show()

# %%
q_original = 1./sigma_en_el.K
q_New      = 1./(40/3*sigma_en_el.Omega11 - 32./3.*sigma_en_el.Omega12 + 32./15.*sigma_en_el.Omega13)

# Plot the data
f, ax = plt.subplots()
ax.plot(sigma_en_el.Temperature, q_New/q_original)
ax.set_ylabel(r'$q^{Boltz}/q^{BGK}$')
ax.set_xlabel(r'$T_e$ [eV]')
#ax.set_yscale('log')
ax.set_xlim([2, 10])
#ax.set_ylim([1e-16, 1e-12])
#plt.legend(loc = 'best', fontsize = 10)

ax.grid(True)

plt.show()

# %% [markdown]
# ### Plot the fit of the rates

# %% [markdown]
# We approximate the rates as:
#
# $$ K, \Omega = AT_e^{-F}\exp\left(-B/T_e + C/T_e^2 - D/T_e^3 + E/T_e^4\right)~[m^3 s^{-1}] $$

# %%
sigma_en_el.fitRate()
sigma_ee_el.fitRate()
sigma_en_exc_1.fitRate()
sigma_en_exc_2.fitRate()
sigma_en_exc_3.fitRate()
sigma_en_iz.fitRate()

# Plot the data
f, ax = plt.subplots()

sigma_en_el.plotFitRate(ax)
sigma_en_el.plotRate(ax)
sigma_ee_el.plotFitRate(ax)
sigma_ee_el.plotRate(ax)
sigma_en_exc_1.plotFitRate(ax)
sigma_en_exc_1.plotRate(ax)
sigma_en_exc_2.plotFitRate(ax)
sigma_en_exc_2.plotRate(ax)
sigma_en_exc_3.plotFitRate(ax)
sigma_en_exc_3.plotRate(ax)
sigma_en_iz.plotFitRate(ax)
sigma_en_iz.plotRate(ax)

ax.set_ylabel(r'$K$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_e$ [eV]')
ax.set_yscale('log')
ax.set_xlim([2, 10])
#ax.set_ylim([1e-16, 1e-12])
plt.legend(loc = 'best', fontsize = 10)

ax.grid(True)

plt.show()

# %%
print(sigma_en_el.name,"= \t", sigma_en_el.Coeffs)
print(sigma_ee_el.name,"= \t", sigma_ee_el.Coeffs)
print(sigma_en_exc_1.name,"= \t", sigma_en_exc_1.Coeffs)
print(sigma_en_exc_2.name,"= \t", sigma_en_exc_2.Coeffs)
print(sigma_en_exc_3.name,"= \t", sigma_en_exc_3.Coeffs)
print(sigma_en_iz.name,"= \t", sigma_en_iz.Coeffs)
# Out:
# Ar-e (Elastic) = 	 [1.98120325e-12 9.03314491e+00 6.56993998e+00 2.23461973e+00
#  0.00000000e+00 6.21159262e-01]
# e-e = 	 [2.72696256e-10 2.88193861e-01 1.63174936e-01 5.29767705e-02
#  0.00000000e+00 1.28676732e+00]
# Ar-e (11.55 eV) = 	 [ 1.15561709e-14  1.66315504e+01  1.79938399e+01  2.42573440e+01
#   0.00000000e+00 -8.37765059e-02]
# Ar-e (13.00 eV) = 	 [4.08622499e-14 1.84824720e+01 1.07447814e+01 1.09473690e+01
#  0.00000000e+00 1.30557814e-01]
# Ar-e (14.00 eV) = 	 [ 4.69464198e-15  1.61959675e+01  7.24967917e+00  9.58306804e+00
#   0.00000000e+00 -4.39649745e-01]
# Ar-e (Ioniz.) = 	 [ 5.07167444e-14  1.92526439e+01  5.84426437e+00  5.13844662e+00
#   0.00000000e+00 -3.07521744e-01]

# %%
sigma_en_el.fitOmega11()
sigma_en_exc_1.fitOmega11()
sigma_en_exc_2.fitOmega11()
sigma_en_exc_3.fitOmega11()
#sigma_en_exc_4.fitOmega11()

# Plot the data
f, ax = plt.subplots()

sigma_en_el.plotFitOmega11(ax)
sigma_en_el.plotOmega11(ax)
sigma_en_exc_1.plotFitOmega11(ax)
sigma_en_exc_1.plotOmega11(ax)
sigma_en_exc_2.plotFitOmega11(ax)
sigma_en_exc_2.plotOmega11(ax)
sigma_en_exc_3.plotFitOmega11(ax)
sigma_en_exc_3.plotOmega11(ax)
#sigma_en_exc_4.plotFitOmega11(ax)
#sigma_en_exc_4.plotOmega11(ax)

ax.set_ylabel(r'$\Omega^{(1,1)}$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_e$ [eV]')
ax.set_yscale('log')
ax.set_xlim([2, 10])
#ax.set_ylim([1e-16, 1e-12])
#plt.legend(loc = 'best', fontsize = 10)

ax.grid(True)

plt.show()

print(sigma_en_el.name,"= \t", sigma_en_el.CoeffsOmega11[0])
print(sigma_en_exc_1.name,"= \t", sigma_en_exc_1.CoeffsOmega11[0])
print(sigma_en_exc_2.name,"= \t", sigma_en_exc_2.CoeffsOmega11[0])
print(sigma_en_exc_3.name,"= \t", sigma_en_exc_3.CoeffsOmega11[0])
#print(sigma_en_exc_4.name,"= \t", sigma_en_exc_4.CoeffsOmega11[0])
# Out:
# Ar-e (Elastic) = 	 [ 5.14396560e-13  5.96360177e+00 -1.05317635e-01 -3.79206431e+00
#  -2.01297074e+00  8.25661177e-01]
# Ar-e (11.55 eV) = 	 [1.15344612e-14 1.92197902e+01 3.70317809e+01 7.08543451e+01
#  4.51266468e+01 2.99515540e-01]
# Ar-e (13.00 eV) = 	 [1.74707993e-14 1.42745417e+01 3.44741628e+00 5.44420196e+00
#  3.47606887e+00 3.36116640e-01]
# Ar-e (14.00 eV) = 	 [ 2.37406950e-15  1.40564388e+01  1.09257461e+01  2.96461657e+01
#   2.52746981e+01 -2.68157103e-01]

# %%
sigma_en_el.fitOmega12()
sigma_en_exc_1.fitOmega12()
sigma_en_exc_2.fitOmega12()
sigma_en_exc_3.fitOmega12()
#sigma_en_exc_4.fitOmega12()

# Plot the data
f, ax = plt.subplots()

sigma_en_el.plotFitOmega12(ax)
sigma_en_el.plotOmega12(ax)
sigma_en_exc_1.plotFitOmega12(ax)
sigma_en_exc_1.plotOmega12(ax)
sigma_en_exc_2.plotFitOmega12(ax)
sigma_en_exc_2.plotOmega12(ax)
sigma_en_exc_3.plotFitOmega12(ax)
sigma_en_exc_3.plotOmega12(ax)
#sigma_en_exc_4.plotFitOmega12(ax)
#sigma_en_exc_4.plotOmega12(ax)

ax.set_ylabel(r'$\Omega^{(1,2)}$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_e$ [eV]')
ax.set_yscale('log')
ax.set_xlim([2, 10])
#ax.set_ylim([1e-16, 1e-12])
#plt.legend(loc = 'best', fontsize = 10)

ax.grid(True)

plt.show()

print(sigma_en_el.name,"= \t", sigma_en_el.CoeffsOmega12[0])
print(sigma_en_exc_1.name,"= \t", sigma_en_exc_1.CoeffsOmega12[0])
print(sigma_en_exc_2.name,"= \t", sigma_en_exc_2.CoeffsOmega12[0])
print(sigma_en_exc_3.name,"= \t", sigma_en_exc_3.CoeffsOmega12[0])
#print(sigma_en_exc_4.name,"= \t", sigma_en_exc_4.CoeffsOmega12[0])
# Out:
# Ar-e (Elastic) = 	 [ 7.83630647e-13  2.05529710e+00 -6.47484875e+00 -8.81382194e+00
#  -3.58570590e+00  7.98417408e-01]
# Ar-e (11.55 eV) = 	 [7.68027252e-14 1.98430440e+01 4.11219635e+01 7.16907047e+01
#  4.21475950e+01 5.59759553e-01]
# Ar-e (13.00 eV) = 	 [ 4.38239845e-14  9.21637983e+00 -6.74396849e+00 -1.01365699e+01
#  -6.98563274e+00  3.68594329e-01]
# Ar-e (14.00 eV) = 	 [ 1.17959450e-14  1.34136449e+01  1.72184476e+01  4.32112422e+01
#   3.25000472e+01 -1.27914246e-01]

# %%
sigma_en_el.fitOmega13()
sigma_en_exc_1.fitOmega13()
sigma_en_exc_2.fitOmega13()
sigma_en_exc_3.fitOmega13()
#sigma_en_exc_4.fitOmega13()

# Plot the data
f, ax = plt.subplots()

sigma_en_el.plotFitOmega13(ax)
sigma_en_el.plotOmega13(ax)
sigma_en_exc_1.plotFitOmega13(ax)
sigma_en_exc_1.plotOmega13(ax)
sigma_en_exc_2.plotFitOmega13(ax)
sigma_en_exc_2.plotOmega13(ax)
sigma_en_exc_3.plotFitOmega13(ax)
sigma_en_exc_3.plotOmega13(ax)
#sigma_en_exc_4.plotFitOmega13(ax)
#sigma_en_exc_4.plotOmega13(ax)

ax.set_ylabel(r'$\Omega^{(1,3)}$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_e$ [eV]')
ax.set_yscale('log')
ax.set_xlim([2, 10])
#ax.set_ylim([1e-16, 1e-12])
#plt.legend(loc = 'best', fontsize = 10)

ax.grid(True)

plt.show()

print(sigma_en_el.name,"= \t", sigma_en_el.CoeffsOmega13[0])
print(sigma_en_exc_1.name,"= \t", sigma_en_exc_1.CoeffsOmega13[0])
print(sigma_en_exc_2.name,"= \t", sigma_en_exc_2.CoeffsOmega13[0])
print(sigma_en_exc_3.name,"= \t", sigma_en_exc_3.CoeffsOmega13[0])
#print(sigma_en_exc_4.name,"= \t", sigma_en_exc_4.CoeffsOmega11[0])
# Out:
# Ar-e (Elastic) = 	 [ 1.48759985e-12 -6.65515444e-01 -9.02256979e+00 -9.39183028e+00
#  -3.33749066e+00  7.05887866e-01]
# Ar-e (11.55 eV) = 	 [4.47299010e-13 1.89895734e+01 3.76517998e+01 5.85471781e+01
#  3.10151209e+01 7.18884546e-01]
# Ar-e (13.00 eV) = 	 [ 1.22064098e-13  5.42262621e+00 -1.15677613e+01 -1.48484341e+01
#  -8.92099262e+00  3.40137073e-01]
# Ar-e (14.00 eV) = 	 [8.92344827e-14 1.48964279e+01 2.83374559e+01 6.11877626e+01
#  4.09862361e+01 5.14331863e-02]

# %%
sigma_en_el.fitOmega22()
sigma_ee_el.fitOmega22()
sigma_en_exc_1.fitOmega22()
sigma_en_exc_2.fitOmega22()
sigma_en_exc_3.fitOmega22()
sigma_en_iz.fitRate()

# Plot the data
f, ax = plt.subplots()

sigma_en_el.plotFitOmega22(ax)
sigma_en_el.plotOmega22(ax)
sigma_ee_el.plotFitOmega22(ax)
sigma_ee_el.plotOmega22(ax)
sigma_en_exc_1.plotFitOmega22(ax)
sigma_en_exc_1.plotOmega22(ax)
sigma_en_exc_2.plotFitOmega22(ax)
sigma_en_exc_2.plotOmega22(ax)
sigma_en_exc_3.plotOmega22(ax)
sigma_en_exc_3.plotFitOmega22(ax)


ax.set_ylabel(r'$\Omega^{(2,2)}$ $[m^{2}]$')
ax.set_xlabel(r'$T_e$ [eV]')
ax.set_yscale('log')
ax.set_xlim([2, 10])
plt.legend(loc = 'best', fontsize = 10)

ax.grid(True)

plt.show()


print(sigma_en_el.name,"= \t", sigma_en_el.CoeffsOmega22[0])
print(sigma_ee_el.name,"= \t", sigma_ee_el.CoeffsOmega22[0])
print(sigma_en_exc_1.name,"= \t", sigma_en_exc_1.CoeffsOmega22[0])
print(sigma_en_exc_2.name,"= \t", sigma_en_exc_2.CoeffsOmega22[0])
print(sigma_en_exc_3.name,"= \t", sigma_en_exc_3.CoeffsOmega22[0])
# Out:
# Ar-e (Elastic) = 	 [ 5.22420425e-13  2.05529704e+00 -6.47484890e+00 -8.81382213e+00
#  -3.58570598e+00  7.98417404e-01]
# e-e = 	 [1.55817985e-11 1.82370919e-01 1.62865510e-01 1.11911292e-01
#  3.33901794e-02 1.39648881e+00]
# Ar-e (11.55 eV) = 	 [5.12012805e-14 1.98429668e+01 4.11215732e+01 7.16896936e+01
#  4.21466396e+01 5.59757054e-01]
# Ar-e (13.00 eV) = 	 [ 2.92159849e-14  9.21637858e+00 -6.74397510e+00 -1.01365883e+01
#  -6.98565183e+00  3.68594290e-01]
# Ar-e (14.00 eV) = 	 [ 7.86395051e-15  1.34136323e+01  1.72183789e+01  4.32110479e+01
#   3.24998450e+01 -1.27914631e-01]

# %% [markdown]
# ## Ion collisions

# %% [markdown]
# ### Plot the momentum transfer cross-sections

# %%
# Define the cross-section
sigma_Ar_ce    = CS.CrossSection(name="Ar-Ar+ (charge-exchange)", mass=phy_const.m_u*39.948, mechanism="ion-neutral")
sigma_Ar_iso   = CS.CrossSection(name="Ar-Ar+ (isotropic)", mass=phy_const.m_u*39.948, mechanism="ion-neutral")

# Read the data
sigma_Ar_ce.readData("../src/CollisionalData/CrossSections/ArReducedSet/Ar_Ar+_CHARGE_EXCHANGE_CROSS_SECTION.txt")
sigma_Ar_iso.readData("../src/CollisionalData/CrossSections/ArReducedSet/Ar_Ar+_ISOTROPIC_CROSS_SECTION.txt")

# %%
# Plot the data
f, ax = plt.subplots()

sigma_Ar_ce.plotSigma(ax)
sigma_Ar_iso.plotSigma(ax)

ax.set_ylabel(r'$\sigma$ $[m^{2}]$')
ax.set_xlabel('E [eV]')
ax.set_yscale('log')
ax.set_xscale('log')
#ax.set_xlim([1e-4, 1e0])
plt.legend(loc = 'best', fontsize = 10)
plt.title("Collisions with ions")

ax.grid(True)

#plt.savefig("./crossSections_ion.pdf", bbox_inches='tight')


plt.show()

# %%
sigma_Ar_iso.computeOmegaM()
sigma_Ar_ce.computeOmegaM()
sigma_Ar_iso.computeOmegaE()
sigma_Ar_ce.computeOmegaE()
# Out:
# reading the rates for  Ar-Ar+ (isotropic)  in  ./../src/CollisionalData/CrossSections/ArReducedSet/Ar_Ar+_ISOTROPIC_CROSS_SECTION_OmegaM.pkl
# reading the rates for  Ar-Ar+ (charge-exchange)  in  ./../src/CollisionalData/CrossSections/ArReducedSet/Ar_Ar+_CHARGE_EXCHANGE_CROSS_SECTION_OmegaM.pkl
# reading the rates for  Ar-Ar+ (isotropic)  in  ./../src/CollisionalData/CrossSections/ArReducedSet/Ar_Ar+_ISOTROPIC_CROSS_SECTION_OmegaE.pkl
# reading the rates for  Ar-Ar+ (charge-exchange)  in  ./../src/CollisionalData/CrossSections/ArReducedSet/Ar_Ar+_CHARGE_EXCHANGE_CROSS_SECTION_OmegaE.pkl

# %%
from matplotlib.lines import Line2D

# Plot the data
f, ax = plt.subplots()

for iMach, Mach in enumerate(sigma_Ar_iso.Mach):
    alpha_color = 1. - (iMach/(len(sigma_Ar_iso.Mach)*1.3))**0.5
    ax.plot(sigma_Ar_ce.Temperature[:],  sigma_Ar_ce.OmegaM[iMach,:], color=sigma_Ar_ce.Color, alpha = alpha_color)
    ax.plot(sigma_Ar_iso.Temperature[:], sigma_Ar_iso.OmegaM[iMach,:], color=sigma_Ar_iso.Color, alpha = alpha_color)
    
ax.text(0.15, 2e-15, r'$M_{+g} = %2.f$'%sigma_Ar_iso.Mach[-1])#, color=sigma_Xen_ce.Color, alpha = alpha_color+0.2)
ax.text(0.25, 1.4e-16, r'$M_{+g} = 0$')#, color=sigma_Xen_ce.Color)

#custom_lines = [Line2D([0], [0], color=sigma_Xen_iso.Color, lw=2),
#                Line2D([0], [0], color=sigma_Xen_ce.Color, lw=2)]

#ax.legend(custom_lines, ['Isotropic', 'Charge-exchange'],loc = 'best', fontsize = 10)
#plt.title("Interpolation")

ax.set_ylabel(r'$\Omega^{(1,1,m)}$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_{+g}$ [eV]')
ax.set_yscale('log')
ax.set_xlim([1e-2, 0.4])
ax.grid(True)
#plt.savefig("/Users/alaguna/Documents/16_PostDoc/77_MomentMethodsPaper/Figures/Omega11m_ions.pdf", bbox_inches='tight')
plt.show()

# %%
# Plot the data
f, ax = plt.subplots()

for iMach, Mach in enumerate(sigma_Ar_iso.Mach):
    alpha_color = 1. - (iMach/(len(sigma_Ar_iso.Mach)*1.3))**0.5
    ax.plot(sigma_Ar_ce.Temperature[:],  sigma_Ar_ce.OmegaE[iMach,:], color=sigma_Ar_ce.Color, alpha = alpha_color)
    ax.plot(sigma_Ar_iso.Temperature[:], sigma_Ar_iso.OmegaE[iMach,:], color=sigma_Ar_iso.Color, alpha = alpha_color)
    
#ax.text(0.15, 2e-15, r'$M_{+g} = 12$')#, color=sigma_Xen_ce.Color, alpha = alpha_color+0.2)
#ax.text(0.25, 1.4e-16, r'$M_{+g} = 0$')#, color=sigma_Xen_ce.Color)

#custom_lines = [Line2D([0], [0], color=sigma_Xen_iso.Color, lw=2),
#                Line2D([0], [0], color=sigma_Xen_ce.Color, lw=2)]

#ax.legend(custom_lines, ['Isotropic', 'Charge-exchange'],loc = 'best', fontsize = 10)
#plt.title("Interpolation")

ax.set_ylabel(r'$\Omega^{(1,1,E)}$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_{+g}$ [eV]')
ax.set_yscale('log')
ax.set_xlim([1e-2, 0.4])
ax.grid(True)
#plt.savefig("/Users/alaguna/Documents/16_PostDoc/77_MomentMethodsPaper/Figures/Omega11m_ions.pdf", bbox_inches='tight')
plt.show()

# %%
sigma_Ar_ce.fitOmegaM()
sigma_Ar_iso.fitOmegaM()

print(sigma_Ar_iso.CoeffsOmegaM)
print(sigma_Ar_ce.CoeffsOmegaM)
print(sigma_Ar_iso.CoeffsOmegaE)
print(sigma_Ar_ce.CoeffsOmegaE)
# Out:
# reading the coefficients for  Ar-Ar+ (charge-exchange) in  ./../src/CollisionalData/CrossSections/ArReducedSet/Ar_Ar+_CHARGE_EXCHANGE_CROSS_SECTION_fitOmegaM.pkl
# reading the coefficients for  Ar-Ar+ (isotropic) in  ./../src/CollisionalData/CrossSections/ArReducedSet/Ar_Ar+_ISOTROPIC_CROSS_SECTION_fitOmegaM.pkl
# ...

# %% [markdown]
# ### Plot the rate integrated over a Maxwellian

# %%
# Compute the rates
sigma_Ar_ce.computeRate()
sigma_Ar_iso.computeRate()


# Plot the data
f, ax = plt.subplots()

sigma_Ar_ce.plotRate(ax)
sigma_Ar_iso.plotRate(ax)


ax.set_ylabel(r'$K$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_i$ [eV]')
#ax.set_yscale('log')
ax.set_xlim([1e-2, 0.5])
# ax.set_ylim([1e-16, 1e-12])
plt.legend(loc = 'best', fontsize = 10)

ax.grid(True)

plt.show()

# %% [markdown]
# ### Plot the fit of the rates
#
# $$ K, \Omega = AT_e^{D}\exp\left(-B/T_e + C/T_e^2\right)~[m^3 s^{-1}] $$

# %%
sigma_Ar_ce.fitRate()
sigma_Ar_iso.fitRate()

# Plot the data
f, ax = plt.subplots()

sigma_Ar_ce.plotFitRate(ax)
sigma_Ar_ce.plotRate(ax)
sigma_Ar_iso.plotFitRate(ax)
sigma_Ar_iso.plotRate(ax)

ax.set_ylabel(r'$K$ $[m^{3}/s]$')
ax.set_xlabel(r'$T_i$ [eV]')
#ax.set_yscale('log')
ax.set_xlim([1.e-2, 1.])
#ax.set_ylim([1e-16, 1e-12])
#plt.legend(loc = 'best', fontsize = 10)

ax.grid(True)

plt.show()

print(sigma_Ar_ce.name,"= \t", sigma_Ar_ce.Coeffs[0])
print(sigma_Ar_iso.name,"= \t", sigma_Ar_iso.Coeffs[0])
# Out:
# Ar-Ar+ (charge-exchange) = 	 1.0378568068345136e-15
# Ar-Ar+ (isotropic) = 	 4.982291919673979e-16

# %% [markdown]
# # Reference values

# %%
m_e  = phy_const.m_e
m_Arp = phy_const.m_u*39.948

pn_mTorr = 3 # mTorr
pn_Pa    = 0.13332237*pn_mTorr
Tn       = 300 # K
L        = 3e-2 #m

ne       = 1e16 # m^3
Te_eV    = 4.51 # eV
Te_K     = 4.51*phy_const.e/phy_const.Boltzmann
Ti_K     = Tn

nn       = pn_Pa/(phy_const.Boltzmann*Tn)

u_Bohm   = np.sqrt(phy_const.Boltzmann*Te_K/m_Arp)
Debye    = np.sqrt(phy_const.epsilon_0*phy_const.Boltzmann*Te_K/(phy_const.e**2*ne))

plasmaFreq = 2*np.pi*np.sqrt(abs(ne*phy_const.e**2/(m_e*phy_const.epsilon_0)))

NBCELLS   = 400
Dx        = 300/NBCELLS
TermVel_e = np.sqrt(2*phy_const.e*Te_eV/m_e)
Dt        = Dx/TermVel_e

t_0      = L/u_Bohm

print("p_gas     = ", pn_mTorr, "mTorr")
print("omega_RF  = ", 8.51999927654e7)
print("Mass_Xe   = ", phy_const.m_u*131.293, "Kg")
print("T_gas     = ", Tn, "K")
print("n_gas     = ", nn, "m^3")
print("L         = ", L, "m")
print("ne        = ", ne, "m")
print("Te        = ", Te_eV, "eV")
print("Te        = ", Te_K, "K")
print("u_Bohm    = ", u_Bohm, "m/s")
print("t_0       = ", t_0,"s")
print("Debye     = ", Debye, "m" )
print("rho_0     = ",ne*m_Arp, "kg/m3")
print("Ref Power = ",ne*phy_const.e*Te_eV*L**3/t_0, "W")
print("Ref Power = ",phy_const.e*ne*u_Bohm*Te_eV/L*L**3, "W")
print("Ref E     = ",Te_eV/L,"V/m")
print()
print()
print("Mass Ratio  = ", m_e/m_Arp)
print("L/Debye     = ", L/Debye)
print("kappa       = ", Tn/Te_K)
#print("nu_in*t0    = ", np.mean(sigma_Xen_iso.K)*nn*t_0)
print("plasma freq = ", plasmaFreq)

print()
print("Dt_plasmaWave = ", 1./plasmaFreq)
print("Dt_Thermal    = ", Dt)
print()
print("omega_RF*t0   = ", 8.51999927654e7*t_0)
print("T_RF          = ", (2*np.pi/8.51999927654e7)/t_0)

# print("Collisional Frequencies")
# print("nu_iz    = ",ionization_freq(nn,Te_eV) ,"Hz")
# print("nu_att   = ",attachment_freq(nn,Te_eV) ,"Hz")
# print("nu_rec   = ",ne*recombination_k() ,"Hz (for alpha = 1)")
# print("nu_el    = ",eI2_freq(nn,Te_eV) ,"Hz")
# print("nu_diss  = ",dissociation_freq(nn,Te_eV) ,"Hz")
# print("nu_IonI2 = ",IonI2_freq(nn) ,"Hz")
# print("nu_ee    = ",coulombCollision(ne, Te_K), "Hz")
# Out:
# p_gas     =  3 mTorr
# omega_RF  =  85199992.7654
# Mass_Xe   =  2.180171556711138e-25 Kg
# T_gas     =  300 K
# n_gas     =  9.65649995038565e+19 m^3
# L         =  0.03 m
# ne        =  1e+16 m
# Te        =  4.51 eV
# Te        =  52336.37672819086 K
# u_Bohm    =  3300.436629780067 m/s
# t_0       =  9.089706413178164e-06 s
# Debye     =  0.00015787284636189524 m
# rho_0     =  6.633521463253681e-10 kg/m3
# Ref Power =  0.02146351486548897 W
# Ref Power =  0.021463514865488975 W
# Ref E     =  150.33333333333334 V/m
#
#
# Mass Ratio  =  1.3732349781275802e-05
# L/Debye     =  190.02634519700982
# kappa       =  0.005732150728699676
# plasma freq =  35446340025.94323
#
# Dt_plasmaWave =  2.8211657374727502e-11
# Dt_Thermal    =  5.954527366284279e-07
#
# omega_RF*t0   =  774.4429206423896
# T_RF          =  0.00811316772315224

# %%
CouloumbLog = 23 - np.log((1e+16*1e-6)**0.5*Te_eV**(-3/2))

nu_ei = 2.91e-6*1e+16*1e-6*CouloumbLog*Te_eV**(-3/2)
nu_ei*t_0
# Out:
# 0.3796389897796944
